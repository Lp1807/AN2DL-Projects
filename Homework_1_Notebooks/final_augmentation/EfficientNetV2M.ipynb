# %% [markdown]
# Here we find a much more aggressive version of augmentation due to the change in parameters compared to the final pipeline.
# The biggest changes have been, going from 2 to 6 transformations of RandAugment carried out on 70% of the images. Increased the severity of Augmix applied to all images.
# We could not stay on an EfficientV2S because it could not learn more. So we moved to an EfficientV2M, which despite giving us more satisfaction this was not enough.
# The best result we got is inside this notebook with a 0.91 accuracy in validation, after 13 hours of training, which is the same result online.

# %%
import neptune
from datetime import date
import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
import tensorflow as tf
import keras_cv as tfkv
from tensorflow import keras as tfk
from keras import applications
from tensorflow.keras.applications import MobileNetV2
from keras import layers as tfkl
from tensorflow.keras import mixed_precision
from io import StringIO
import os
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import to_categorical

import keras_cv

# %% [markdown]
# load the data and split on train and validation we decided not to create a test set in order to have more data and thus decrease the variance.

# %%
data = np.load('Dataset/training_set_cleaned_NODUPLICATE.npz')
X = data['images']
y = data['labels']

# Assuming 'X' and 'y' are defined from the previous code
print("Shape of X:", X.shape)
print("Shape of y:", y.shape)
print("Number of samples:", X.shape[0])
print("Number of features:", X.shape[1:])
print("Unique labels:", np.unique(y))
# Out:
# Shape of X: (11951, 96, 96, 3)
# Shape of y: (11951, 1)
# Number of samples: 11951
# Number of features: (96, 96, 3)
# Unique labels: [0 1 2 3 4 5 6 7]

# %%
# Converting to one-hot encoding
seed = 90
y = tfk.utils.to_categorical(y,len(np.unique(y)))

# Split data into train_val and test sets
X_train, X_val, y_train, y_val = train_test_split(X, y, random_state=seed, test_size=0.2, stratify=np.argmax(y,axis=1))


# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (9560, 96, 96, 3), y_train shape: (9560, 8)
# X_val shape: (2391, 96, 96, 3), y_val shape: (2391, 8)

# %%
def plot_class_distribution(y, title):
  num_samples = np.zeros(8)
  tmp_y = np.argmax(y, axis=1)
  for i in range(8):
    num_samples[i] = np.sum(tmp_y == i)
  plt.bar(range(8), num_samples / np.sum(num_samples))
  plt.xlabel('Class')
  plt.ylabel('Percentage')
  plt.title(title)
  plt.show()

plot_class_distribution(y_train, 'Class Distribution in Training Set')
plot_class_distribution(y_val, 'Class Distribution in Validation Set')

# %% [markdown]
# # Parameters and Hyperparameters

# %%
data_params = {
    'batch_size': 32,
    'input_shape': (96, 96, 3),
    'num_classes': 8,
    'seed': 90
}

HYPERPARAMETERS = {
    "BATCH_SIZE": 32,
    "EPOCHS": 200,
    "LEARNING_RATE": 0.001,
    "LEARNING_DESCENT_PATIENCE": 5,
    "LEARNING_DESCENT_FACTOR": 0.5,
    "EARLY_STOPPING_PATIENCE": 10,
    "DROPOUT": 0.4,
    "LAYERS_FINE_TUNE": 200, #not used
    "MODEL_NAME": "",
    "RAND_AUGMENT_MAGNITUDE": 0.5, #not used
    "RAND_AUGMENT_AUGMENTATIONS_PER_IMAGE": 2 #not used
}

# %% [markdown]
# # Build the model

# %% [markdown]
# ## Augmentations

# %%
AUTO = tf.data.AUTOTUNE

augmix = keras_cv.layers.AugMix(
    value_range=(0, 255),
    severity=0.7,
    num_chains=3,
    chain_depth=[1, 3],
    alpha=1.0,
)

grid_mask = keras_cv.layers.GridMask(
      ratio_factor=(0, 0.5), rotation_factor=0.15, fill_mode="constant", fill_value=0.0)

cutout_constant = keras_cv.layers.RandomCutout(height_factor = 0.5, width_factor = 0.5, fill_mode="constant")

randomZoom = keras_cv.layers.RandomZoom(height_factor=0.5, width_factor=0.5)

hue = keras_cv.layers.RandomHue(factor=0.3, value_range=(0, 255))

channelShuffle = keras_cv.layers.ChannelShuffle(groups=3)

channelShift = keras_cv.layers.RandomChannelShift(value_range=(0, 255),factor=0.3)

simple_aug = tfk.Sequential(
    [
        tfkl.RandomFlip("horizontal_and_vertical"),
        tfkl.RandomRotation(factor=0.3, fill_mode = "nearest"),
        tfkl.RandomZoom(height_factor=0.1, width_factor=0.1, fill_mode = "nearest"),
    ]
)


rand_augment = tfkv.layers.RandAugment(
    value_range=(0, 255),
    augmentations_per_image=6,
    magnitude=0.3,
    rate=0.7,
    geometric = True
)

grid_mask_or_rand_cutout = [
    cutout_constant,
    grid_mask
]

color_trasformations = [
     hue,
     channelShuffle,
     channelShift
]

randAug_or_AugMix = [
     rand_augment,
     augmix
]


def augment(images):
  image = tf.cast(images, tf.uint8)
  images = simple_aug(image)
  images = rand_augment(images)
  images = augmix(images)
  images = keras_cv.layers.RandomChoice(layers=grid_mask_or_rand_cutout)(images)
  images = keras_cv.layers.RandomChoice(layers=color_trasformations)(images)

  return images

# %% [markdown]
# ## Data loaders

# %%
train_data = (
    tf.data.Dataset.from_tensor_slices((X_train, y_train))
    .shuffle(HYPERPARAMETERS['EPOCHS'] * 100)
    .batch(HYPERPARAMETERS['BATCH_SIZE'])
    .map(
        lambda x, y: (augment(x), y),
        num_parallel_calls=AUTO,
    )
    .prefetch(AUTO)
)

val_data = (
    tf.data.Dataset.from_tensor_slices((X_val, y_val))
    .batch(HYPERPARAMETERS['BATCH_SIZE'])
    .map(
        lambda x, y: (augment(x), y),
        num_parallel_calls=AUTO,
    )
    .prefetch(AUTO)
)

# %% [markdown]
# ### Plotting to see the augmentations

# %%
sample_images, _ = next(iter(train_data))
plt.figure(figsize=(10, 10))
for i, image in enumerate(sample_images[:9]):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image.numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# ## Model Definition

# %%
print('Loading model with ImageNet weights...')
MODEL_IMPORTED =tfk.applications.EfficientNetV2M(
    include_top=False,
    weights="imagenet",
    input_shape=data_params['input_shape'],
    pooling="avg",
    classes=8,
    classifier_activation="softmax",
    include_preprocessing=True,
    name="efficientnetv2-m",
)

# Set all layers in the convolutional base to Trainable (will FREEZE initial layers further below).
MODEL_IMPORTED.trainable = True

# Specify the number of layers to fine tune at the end of the convolutional base.
num_layers_fine_tune = 650
num_layers = len(MODEL_IMPORTED.layers)

print("Num_layers fine tune " + str(num_layers_fine_tune))
print("Num_layers: " + str(num_layers))

# Freeze the initial layers in the convolutional base.
for model_layer in MODEL_IMPORTED.layers[:num_layers - num_layers_fine_tune]:
    model_layer.trainable = False

print(f"\nConfigured to fine tune the last", num_layers_fine_tune, "convolutional layers...\n")
# Out:
# Loading model with ImageNet weights...
# Num_layers fine tune 650
# Num_layers: 741
#
# Configured to fine tune the last 650 convolutional layers...

# %%
def build_model():
  """Builds the Keras model.
  """
  inputs = tf.keras.Input(shape=data_params['input_shape'])

  # Wrap the augmentation layer in a tf.function
  # Wrap augment_image in tf.py_function to execute eagerly

  x = MODEL_IMPORTED(inputs)

  x = tfkl.Dense(128, activation='relu')(x)
  x = tfkl.Dropout(HYPERPARAMETERS['DROPOUT'])(x)
  x = tfkl.Dense(64, activation='relu')(x)
  x = tfkl.Dropout(HYPERPARAMETERS['DROPOUT'])(x)


  outputs = tfkl.Dense(data_params['num_classes'], activation='softmax')(x)

  model = tfk.Model(inputs=inputs, outputs=outputs)
  print(model.summary())

  return model

# %%
model = build_model()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_7 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetv2-m (Functional)   │ (None, 1280)           │    53,150,388 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 8)              │           520 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 53,323,132 (203.41 MB)
#  Trainable params: 51,462,708 (196.31 MB)
#  Non-trainable params: 1,860,424 (7.10 MB)
# None

# %%
model.compile(
    
    optimizer=tf.keras.optimizers.AdamW(learning_rate=HYPERPARAMETERS["LEARNING_RATE"]),
    loss=tf.keras.losses.CategoricalFocalCrossentropy(from_logits=False, alpha=0.25, gamma=2.0, axis=-1, reduction="sum_over_batch_size"),
    metrics=['accuracy'],
)

# %% [markdown]
# Configuration of Neptune

# %%
# prompt: class neptune callback

run = neptune.init_run(
    project=f"lp1807/Homework1" , # Replace with your Neptune project
    api_token="API_TOKEN",
    name="EfficientNetV2M-withFineTune_MoreDense_HEAVYAUG_60FT"
)

# Create a NeptuneCallback
class NeptuneCallback(tfk.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        run["model/train/accuracy"].log(logs["accuracy"])
        run["model/train/loss"].log(logs["loss"])
        run["model/val/accuracy"].log(logs["val_accuracy"])
        run["model/val/loss"].log(logs["val_loss"])


def saveNeptune_Drive():

  # Log the entire history dictionary to Neptune
  run["training/history"] = history.history  # <-- This line logs the entire training history

  for epoch in range(len(history.history['accuracy'])):
    run["training/epoch/train_accuracy"].log(history.history['accuracy'][epoch])
    run["training/epoch/val_accuracy"].log(history.history['val_accuracy'][epoch])
    run["training/epoch/train_loss"].log(history.history['loss'][epoch])
    run["training/epoch/val_loss"].log(history.history['val_loss'][epoch])

  model_summary = StringIO()
  model.summary(print_fn=lambda x: model_summary.write(x + "\n"))
  run["model/summary"] = model_summary.getvalue()

  # Log model weights and configuration
  run["model/weights"] = neptune.types.File.as_pickle(model.get_weights())
  run["model/config"] = model.get_config()

  model_file_path = f"EfficientM650.keras"
  model.save(model_file_path)

  # Log the .keras model file to Neptune
  run["model/file"].upload(model_file_path)

  # Convert history to DataFrame and save as CSV
  history_df = pd.DataFrame(history.history)
  history_file_path = f"EfficientM650.csv"
  history_df.to_csv(history_file_path, index=False)

  # Log the CSV file to Neptune
  run["training/history_file"].upload(history_file_path)
  run["notebook"].upload("/content/drive/MyDrive/Colab Notebooks/the_boss.ipynb")

def saveHyperparameters():
    # Saving as Json
    run["hyperparameters"] = HYPERPARAMETERS
# Out:
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/lp1807/Homework1/e/HOM-377

# %%
# Define the checkpoint directory on Google Drive or locally
checkpoint_dir = '/checkpoints/'  # Modify this path as needed
os.makedirs(checkpoint_dir, exist_ok=True)
saveHyperparameters()

neptune_cbk = NeptuneCallback()

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=f"EfficientM650Backup.keras",
    save_weights_only=False,  # Save only model weights, not the entire model
    monitor='val_loss',      # Monitor validation loss for checkpointing
    save_best_only=True,     # Save model at the end of each epoch regardless of improvement
    save_freq = "epoch",                 # Save checkpoint every 5 epochs
    verbose=1                 # Print message when saving a checkpoint
)

# Early stopping callback
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=HYPERPARAMETERS["EARLY_STOPPING_PATIENCE"],  # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True  # Restore model weights from the epoch with the best value of the monitored quantity
)

# ReduceLROnPlateau callback to decrease the learning rate when the validation loss plateaus
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',  # Monitor validation loss
    factor=HYPERPARAMETERS["LEARNING_DESCENT_FACTOR"],  # Reduce the learning rate by a factor of 0.5
    patience=HYPERPARAMETERS["LEARNING_DESCENT_PATIENCE"],  # Number of epochs with no improvement after which learning rate will be reduced
    min_lr=1e-6,  # Lower bound on the learning rate
    verbose=1  # Print out a message when learning rate is reduced
)

# Train the model with the callbacks
history = model.fit(
    train_data,
    epochs=HYPERPARAMETERS["EPOCHS"],
    validation_data=val_data,
    callbacks=[ early_stopping, reduce_lr, checkpoint_callback]  # Include both the callbacks here
)

saveNeptune_Drive()

# Finalize the Neptune run
run.stop()
# Out:
# Epoch 1/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3582 - loss: 0.3015
# Epoch 1: val_loss improved from inf to 0.16525, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 562s 2s/step - accuracy: 0.3585 - loss: 0.3013 - val_accuracy: 0.6257 - val_loss: 0.1652 - learning_rate: 0.0010
# Epoch 2/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5844 - loss: 0.1811
# Epoch 2: val_loss improved from 0.16525 to 0.13070, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 463s 2s/step - accuracy: 0.5844 - loss: 0.1811 - val_accuracy: 0.6583 - val_loss: 0.1307 - learning_rate: 0.0010
# Epoch 3/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6291 - loss: 0.1583
# Epoch 3: val_loss improved from 0.13070 to 0.11539, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 460s 2s/step - accuracy: 0.6291 - loss: 0.1583 - val_accuracy: 0.7139 - val_loss: 0.1154 - learning_rate: 0.0010
# Epoch 4/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6492 - loss: 0.1478
# Epoch 4: val_loss improved from 0.11539 to 0.10794, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 461s 2s/step - accuracy: 0.6492 - loss: 0.1478 - val_accuracy: 0.7039 - val_loss: 0.1079 - learning_rate: 0.0010
# Epoch 5/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6760 - loss: 0.1357
# Epoch 5: val_loss improved from 0.10794 to 0.10411, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 461s 2s/step - accuracy: 0.6760 - loss: 0.1357 - val_accuracy: 0.7286 - val_loss: 0.1041 - learning_rate: 0.0010
# Epoch 6/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6946 - loss: 0.1233
# Epoch 6: val_loss improved from 0.10411 to 0.09253, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 463s 2s/step - accuracy: 0.6946 - loss: 0.1233 - val_accuracy: 0.7478 - val_loss: 0.0925 - learning_rate: 0.0010
# Epoch 7/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7008 - loss: 0.1180
# Epoch 7: val_loss did not improve from 0.09253
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 458s 2s/step - accuracy: 0.7008 - loss: 0.1180 - val_accuracy: 0.7608 - val_loss: 0.0943 - learning_rate: 0.0010
# Epoch 8/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7196 - loss: 0.1163
# Epoch 8: val_loss improved from 0.09253 to 0.08765, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 463s 2s/step - accuracy: 0.7196 - loss: 0.1163 - val_accuracy: 0.7691 - val_loss: 0.0877 - learning_rate: 0.0010
# Epoch 9/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7380 - loss: 0.1045
# Epoch 9: val_loss did not improve from 0.08765
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 460s 2s/step - accuracy: 0.7380 - loss: 0.1045 - val_accuracy: 0.7804 - val_loss: 0.0879 - learning_rate: 0.0010
# Epoch 10/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7272 - loss: 0.1094
# Epoch 10: val_loss improved from 0.08765 to 0.08017, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 465s 2s/step - accuracy: 0.7273 - loss: 0.1094 - val_accuracy: 0.7712 - val_loss: 0.0802 - learning_rate: 0.0010
# Epoch 11/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7552 - loss: 0.0968
# Epoch 11: val_loss improved from 0.08017 to 0.07611, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 462s 2s/step - accuracy: 0.7552 - loss: 0.0968 - val_accuracy: 0.7963 - val_loss: 0.0761 - learning_rate: 0.0010
# Epoch 12/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7614 - loss: 0.0983
# Epoch 12: val_loss did not improve from 0.07611
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 461s 2s/step - accuracy: 0.7614 - loss: 0.0983 - val_accuracy: 0.7926 - val_loss: 0.0801 - learning_rate: 0.0010
# Epoch 13/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7511 - loss: 0.1010
# Epoch 13: val_loss did not improve from 0.07611
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 461s 2s/step - accuracy: 0.7511 - loss: 0.1010 - val_accuracy: 0.7696 - val_loss: 0.0810 - learning_rate: 0.0010
# Epoch 14/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7582 - loss: 0.0967
# Epoch 14: val_loss did not improve from 0.07611
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 460s 2s/step - accuracy: 0.7582 - loss: 0.0967 - val_accuracy: 0.7963 - val_loss: 0.0778 - learning_rate: 0.0010
# Epoch 15/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7661 - loss: 0.0897
# Epoch 15: val_loss improved from 0.07611 to 0.07576, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 465s 2s/step - accuracy: 0.7661 - loss: 0.0897 - val_accuracy: 0.7884 - val_loss: 0.0758 - learning_rate: 0.0010
# Epoch 16/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7614 - loss: 0.0924
# Epoch 16: val_loss improved from 0.07576 to 0.06655, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 462s 2s/step - accuracy: 0.7614 - loss: 0.0924 - val_accuracy: 0.8059 - val_loss: 0.0666 - learning_rate: 0.0010
# Epoch 17/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7722 - loss: 0.0903
# Epoch 17: val_loss improved from 0.06655 to 0.06385, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 464s 2s/step - accuracy: 0.7722 - loss: 0.0903 - val_accuracy: 0.8189 - val_loss: 0.0638 - learning_rate: 0.0010
# Epoch 18/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7852 - loss: 0.0875
# Epoch 18: val_loss did not improve from 0.06385
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 457s 2s/step - accuracy: 0.7851 - loss: 0.0875 - val_accuracy: 0.8348 - val_loss: 0.0648 - learning_rate: 0.0010
# Epoch 19/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7933 - loss: 0.0838
# Epoch 19: val_loss did not improve from 0.06385
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 458s 2s/step - accuracy: 0.7933 - loss: 0.0838 - val_accuracy: 0.7963 - val_loss: 0.0742 - learning_rate: 0.0010
# Epoch 20/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7843 - loss: 0.0852
# Epoch 20: val_loss did not improve from 0.06385
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 458s 2s/step - accuracy: 0.7843 - loss: 0.0852 - val_accuracy: 0.8110 - val_loss: 0.0675 - learning_rate: 0.0010
# Epoch 21/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7937 - loss: 0.0857
# Epoch 21: val_loss improved from 0.06385 to 0.06363, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 463s 2s/step - accuracy: 0.7937 - loss: 0.0857 - val_accuracy: 0.8223 - val_loss: 0.0636 - learning_rate: 0.0010
# Epoch 22/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8001 - loss: 0.0782
# Epoch 22: val_loss improved from 0.06363 to 0.06223, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 465s 2s/step - accuracy: 0.8001 - loss: 0.0782 - val_accuracy: 0.8340 - val_loss: 0.0622 - learning_rate: 0.0010
# Epoch 23/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7936 - loss: 0.0809
# Epoch 23: val_loss did not improve from 0.06223
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 458s 2s/step - accuracy: 0.7936 - loss: 0.0809 - val_accuracy: 0.8197 - val_loss: 0.0623 - learning_rate: 0.0010
# Epoch 24/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8061 - loss: 0.0770
# Epoch 24: val_loss did not improve from 0.06223
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 462s 2s/step - accuracy: 0.8061 - loss: 0.0771 - val_accuracy: 0.8214 - val_loss: 0.0629 - learning_rate: 0.0010
# Epoch 25/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8023 - loss: 0.0811
# Epoch 25: val_loss did not improve from 0.06223
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 459s 2s/step - accuracy: 0.8023 - loss: 0.0810 - val_accuracy: 0.8202 - val_loss: 0.0664 - learning_rate: 0.0010
# Epoch 26/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8037 - loss: 0.0744
# Epoch 26: val_loss improved from 0.06223 to 0.05965, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 464s 2s/step - accuracy: 0.8037 - loss: 0.0744 - val_accuracy: 0.8432 - val_loss: 0.0596 - learning_rate: 0.0010
# Epoch 27/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8119 - loss: 0.0763
# Epoch 27: val_loss improved from 0.05965 to 0.05229, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 465s 2s/step - accuracy: 0.8119 - loss: 0.0763 - val_accuracy: 0.8532 - val_loss: 0.0523 - learning_rate: 0.0010
# Epoch 28/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8114 - loss: 0.0732
# Epoch 28: val_loss did not improve from 0.05229
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 458s 2s/step - accuracy: 0.8114 - loss: 0.0732 - val_accuracy: 0.8327 - val_loss: 0.0657 - learning_rate: 0.0010
# Epoch 29/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8042 - loss: 0.0772
# Epoch 29: val_loss did not improve from 0.05229
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 458s 2s/step - accuracy: 0.8042 - loss: 0.0772 - val_accuracy: 0.8402 - val_loss: 0.0578 - learning_rate: 0.0010
# Epoch 30/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8007 - loss: 0.0788
# Epoch 30: val_loss did not improve from 0.05229
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 458s 2s/step - accuracy: 0.8007 - loss: 0.0788 - val_accuracy: 0.8381 - val_loss: 0.0573 - learning_rate: 0.0010
# Epoch 31/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8118 - loss: 0.0720
# Epoch 31: val_loss did not improve from 0.05229
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 459s 2s/step - accuracy: 0.8118 - loss: 0.0720 - val_accuracy: 0.8369 - val_loss: 0.0596 - learning_rate: 0.0010
# Epoch 32/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8110 - loss: 0.0681
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 32: val_loss did not improve from 0.05229
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 458s 2s/step - accuracy: 0.8111 - loss: 0.0681 - val_accuracy: 0.8415 - val_loss: 0.0583 - learning_rate: 0.0010
# Epoch 33/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8262 - loss: 0.0690
# Epoch 33: val_loss improved from 0.05229 to 0.05097, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 461s 2s/step - accuracy: 0.8262 - loss: 0.0689 - val_accuracy: 0.8473 - val_loss: 0.0510 - learning_rate: 5.0000e-04
# Epoch 34/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8349 - loss: 0.0596
# Epoch 34: val_loss improved from 0.05097 to 0.04678, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 458s 2s/step - accuracy: 0.8350 - loss: 0.0596 - val_accuracy: 0.8591 - val_loss: 0.0468 - learning_rate: 5.0000e-04
# Epoch 35/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8351 - loss: 0.0622
# Epoch 35: val_loss did not improve from 0.04678
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 452s 1s/step - accuracy: 0.8351 - loss: 0.0622 - val_accuracy: 0.8553 - val_loss: 0.0486 - learning_rate: 5.0000e-04
# Epoch 36/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8374 - loss: 0.0598
# Epoch 36: val_loss improved from 0.04678 to 0.04650, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 460s 2s/step - accuracy: 0.8374 - loss: 0.0598 - val_accuracy: 0.8511 - val_loss: 0.0465 - learning_rate: 5.0000e-04
# Epoch 37/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8396 - loss: 0.0574
# Epoch 37: val_loss improved from 0.04650 to 0.04481, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 461s 2s/step - accuracy: 0.8396 - loss: 0.0574 - val_accuracy: 0.8666 - val_loss: 0.0448 - learning_rate: 5.0000e-04
# Epoch 38/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8361 - loss: 0.0603
# Epoch 38: val_loss did not improve from 0.04481
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 456s 2s/step - accuracy: 0.8361 - loss: 0.0603 - val_accuracy: 0.8645 - val_loss: 0.0482 - learning_rate: 5.0000e-04
# Epoch 39/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8421 - loss: 0.0624
# Epoch 39: val_loss improved from 0.04481 to 0.04421, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 460s 2s/step - accuracy: 0.8422 - loss: 0.0624 - val_accuracy: 0.8795 - val_loss: 0.0442 - learning_rate: 5.0000e-04
# Epoch 40/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8443 - loss: 0.0604
# Epoch 40: val_loss improved from 0.04421 to 0.04367, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 460s 2s/step - accuracy: 0.8443 - loss: 0.0604 - val_accuracy: 0.8586 - val_loss: 0.0437 - learning_rate: 5.0000e-04
# Epoch 41/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.8559 - loss: 0.0533
# Epoch 41: val_loss did not improve from 0.04367
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 4059s 14s/step - accuracy: 0.8558 - loss: 0.0533 - val_accuracy: 0.8670 - val_loss: 0.0487 - learning_rate: 5.0000e-04
# Epoch 42/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8458 - loss: 0.0586
# Epoch 42: val_loss did not improve from 0.04367
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 454s 2s/step - accuracy: 0.8458 - loss: 0.0586 - val_accuracy: 0.8720 - val_loss: 0.0460 - learning_rate: 5.0000e-04
# Epoch 43/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8543 - loss: 0.0535
# Epoch 43: val_loss did not improve from 0.04367
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 456s 2s/step - accuracy: 0.8543 - loss: 0.0535 - val_accuracy: 0.8599 - val_loss: 0.0456 - learning_rate: 5.0000e-04
# Epoch 44/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8462 - loss: 0.0600
# Epoch 44: val_loss did not improve from 0.04367
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 455s 2s/step - accuracy: 0.8462 - loss: 0.0600 - val_accuracy: 0.8653 - val_loss: 0.0453 - learning_rate: 5.0000e-04
# Epoch 45/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8517 - loss: 0.0546
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 45: val_loss did not improve from 0.04367
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 456s 2s/step - accuracy: 0.8517 - loss: 0.0546 - val_accuracy: 0.8674 - val_loss: 0.0475 - learning_rate: 5.0000e-04
# Epoch 46/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8477 - loss: 0.0583
# Epoch 46: val_loss improved from 0.04367 to 0.04361, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 458s 2s/step - accuracy: 0.8477 - loss: 0.0583 - val_accuracy: 0.8741 - val_loss: 0.0436 - learning_rate: 2.5000e-04
# Epoch 47/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8548 - loss: 0.0518
# Epoch 47: val_loss improved from 0.04361 to 0.04026, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 460s 2s/step - accuracy: 0.8548 - loss: 0.0518 - val_accuracy: 0.8871 - val_loss: 0.0403 - learning_rate: 2.5000e-04
# Epoch 48/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8646 - loss: 0.0489
# Epoch 48: val_loss did not improve from 0.04026
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 465s 2s/step - accuracy: 0.8646 - loss: 0.0489 - val_accuracy: 0.8716 - val_loss: 0.0408 - learning_rate: 2.5000e-04
# Epoch 49/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8669 - loss: 0.0450
# Epoch 49: val_loss did not improve from 0.04026
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 465s 2s/step - accuracy: 0.8669 - loss: 0.0450 - val_accuracy: 0.8850 - val_loss: 0.0413 - learning_rate: 2.5000e-04
# Epoch 50/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8673 - loss: 0.0443
# Epoch 50: val_loss improved from 0.04026 to 0.03977, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 469s 2s/step - accuracy: 0.8673 - loss: 0.0443 - val_accuracy: 0.8892 - val_loss: 0.0398 - learning_rate: 2.5000e-04
# Epoch 51/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8653 - loss: 0.0476
# Epoch 51: val_loss improved from 0.03977 to 0.03760, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 469s 2s/step - accuracy: 0.8653 - loss: 0.0476 - val_accuracy: 0.8808 - val_loss: 0.0376 - learning_rate: 2.5000e-04
# Epoch 52/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8691 - loss: 0.0486
# Epoch 52: val_loss did not improve from 0.03760
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 464s 2s/step - accuracy: 0.8691 - loss: 0.0486 - val_accuracy: 0.8737 - val_loss: 0.0415 - learning_rate: 2.5000e-04
# Epoch 53/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8696 - loss: 0.0480
# Epoch 53: val_loss improved from 0.03760 to 0.03637, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 469s 2s/step - accuracy: 0.8696 - loss: 0.0480 - val_accuracy: 0.8887 - val_loss: 0.0364 - learning_rate: 2.5000e-04
# Epoch 54/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8710 - loss: 0.0454
# Epoch 54: val_loss did not improve from 0.03637
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 467s 2s/step - accuracy: 0.8710 - loss: 0.0454 - val_accuracy: 0.8904 - val_loss: 0.0388 - learning_rate: 2.5000e-04
# Epoch 55/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8693 - loss: 0.0461
# Epoch 55: val_loss did not improve from 0.03637
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 467s 2s/step - accuracy: 0.8693 - loss: 0.0461 - val_accuracy: 0.8804 - val_loss: 0.0396 - learning_rate: 2.5000e-04
# Epoch 56/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8736 - loss: 0.0464
# Epoch 56: val_loss did not improve from 0.03637
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 460s 2s/step - accuracy: 0.8736 - loss: 0.0464 - val_accuracy: 0.8929 - val_loss: 0.0365 - learning_rate: 2.5000e-04
# Epoch 57/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8693 - loss: 0.0467
# Epoch 57: val_loss did not improve from 0.03637
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 460s 2s/step - accuracy: 0.8693 - loss: 0.0467 - val_accuracy: 0.8783 - val_loss: 0.0408 - learning_rate: 2.5000e-04
# Epoch 58/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8669 - loss: 0.0492
# Epoch 58: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 58: val_loss did not improve from 0.03637
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 459s 2s/step - accuracy: 0.8669 - loss: 0.0492 - val_accuracy: 0.8934 - val_loss: 0.0365 - learning_rate: 2.5000e-04
# Epoch 59/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8768 - loss: 0.0465
# Epoch 59: val_loss improved from 0.03637 to 0.03301, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 464s 2s/step - accuracy: 0.8768 - loss: 0.0465 - val_accuracy: 0.8854 - val_loss: 0.0330 - learning_rate: 1.2500e-04
# Epoch 60/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8780 - loss: 0.0452
# Epoch 60: val_loss did not improve from 0.03301
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 458s 2s/step - accuracy: 0.8780 - loss: 0.0452 - val_accuracy: 0.8921 - val_loss: 0.0345 - learning_rate: 1.2500e-04
# Epoch 61/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8778 - loss: 0.0447
# Epoch 61: val_loss did not improve from 0.03301
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 460s 2s/step - accuracy: 0.8778 - loss: 0.0447 - val_accuracy: 0.8954 - val_loss: 0.0379 - learning_rate: 1.2500e-04
# Epoch 62/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8770 - loss: 0.0452
# Epoch 62: val_loss did not improve from 0.03301
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 457s 2s/step - accuracy: 0.8770 - loss: 0.0452 - val_accuracy: 0.8938 - val_loss: 0.0355 - learning_rate: 1.2500e-04
# Epoch 63/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8780 - loss: 0.0422
# Epoch 63: val_loss did not improve from 0.03301
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 450s 1s/step - accuracy: 0.8780 - loss: 0.0422 - val_accuracy: 0.8871 - val_loss: 0.0341 - learning_rate: 1.2500e-04
# Epoch 64/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8777 - loss: 0.0418
# Epoch 64: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 64: val_loss did not improve from 0.03301
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 459s 2s/step - accuracy: 0.8777 - loss: 0.0418 - val_accuracy: 0.8996 - val_loss: 0.0340 - learning_rate: 1.2500e-04
# Epoch 65/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8851 - loss: 0.0398
# Epoch 65: val_loss did not improve from 0.03301
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 463s 2s/step - accuracy: 0.8851 - loss: 0.0398 - val_accuracy: 0.9042 - val_loss: 0.0338 - learning_rate: 6.2500e-05
# Epoch 66/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8796 - loss: 0.0438
# Epoch 66: val_loss improved from 0.03301 to 0.03258, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 469s 2s/step - accuracy: 0.8796 - loss: 0.0438 - val_accuracy: 0.8929 - val_loss: 0.0326 - learning_rate: 6.2500e-05
# Epoch 67/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8873 - loss: 0.0424
# Epoch 67: val_loss did not improve from 0.03258
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 466s 2s/step - accuracy: 0.8873 - loss: 0.0424 - val_accuracy: 0.9034 - val_loss: 0.0340 - learning_rate: 6.2500e-05
# Epoch 68/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8857 - loss: 0.0417
# Epoch 68: val_loss did not improve from 0.03258
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 466s 2s/step - accuracy: 0.8857 - loss: 0.0417 - val_accuracy: 0.8988 - val_loss: 0.0350 - learning_rate: 6.2500e-05
# Epoch 69/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8820 - loss: 0.0429
# Epoch 69: val_loss did not improve from 0.03258
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 466s 2s/step - accuracy: 0.8820 - loss: 0.0429 - val_accuracy: 0.8854 - val_loss: 0.0384 - learning_rate: 6.2500e-05
# Epoch 70/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8777 - loss: 0.0449
# Epoch 70: val_loss did not improve from 0.03258
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 467s 2s/step - accuracy: 0.8777 - loss: 0.0449 - val_accuracy: 0.8854 - val_loss: 0.0372 - learning_rate: 6.2500e-05
# Epoch 71/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8906 - loss: 0.0387
# Epoch 71: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 71: val_loss did not improve from 0.03258
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 463s 2s/step - accuracy: 0.8905 - loss: 0.0387 - val_accuracy: 0.9038 - val_loss: 0.0336 - learning_rate: 6.2500e-05
# Epoch 72/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8917 - loss: 0.0387
# Epoch 72: val_loss did not improve from 0.03258
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 465s 2s/step - accuracy: 0.8917 - loss: 0.0387 - val_accuracy: 0.8992 - val_loss: 0.0375 - learning_rate: 3.1250e-05
# Epoch 73/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8825 - loss: 0.0423
# Epoch 73: val_loss did not improve from 0.03258
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 464s 2s/step - accuracy: 0.8825 - loss: 0.0423 - val_accuracy: 0.8992 - val_loss: 0.0336 - learning_rate: 3.1250e-05
# Epoch 74/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8852 - loss: 0.0390
# Epoch 74: val_loss did not improve from 0.03258
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 465s 2s/step - accuracy: 0.8852 - loss: 0.0390 - val_accuracy: 0.9000 - val_loss: 0.0336 - learning_rate: 3.1250e-05
# Epoch 75/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8888 - loss: 0.0372
# Epoch 75: val_loss improved from 0.03258 to 0.03055, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 469s 2s/step - accuracy: 0.8888 - loss: 0.0372 - val_accuracy: 0.9009 - val_loss: 0.0306 - learning_rate: 3.1250e-05
# Epoch 76/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8977 - loss: 0.0359
# Epoch 76: val_loss did not improve from 0.03055
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 462s 2s/step - accuracy: 0.8977 - loss: 0.0359 - val_accuracy: 0.8946 - val_loss: 0.0348 - learning_rate: 3.1250e-05
# Epoch 77/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8838 - loss: 0.0407
# Epoch 77: val_loss did not improve from 0.03055
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 463s 2s/step - accuracy: 0.8838 - loss: 0.0407 - val_accuracy: 0.9013 - val_loss: 0.0357 - learning_rate: 3.1250e-05
# Epoch 78/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8878 - loss: 0.0384
# Epoch 78: val_loss did not improve from 0.03055
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 462s 2s/step - accuracy: 0.8878 - loss: 0.0384 - val_accuracy: 0.9021 - val_loss: 0.0333 - learning_rate: 3.1250e-05
# Epoch 79/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8843 - loss: 0.0402
# Epoch 79: val_loss improved from 0.03055 to 0.02971, saving model to EfficientM650Backup.keras
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 468s 2s/step - accuracy: 0.8843 - loss: 0.0402 - val_accuracy: 0.9076 - val_loss: 0.0297 - learning_rate: 3.1250e-05
# Epoch 80/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8837 - loss: 0.0414
# Epoch 80: val_loss did not improve from 0.02971
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 466s 2s/step - accuracy: 0.8837 - loss: 0.0414 - val_accuracy: 0.9030 - val_loss: 0.0322 - learning_rate: 3.1250e-05
# Epoch 81/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8845 - loss: 0.0406
# Epoch 81: val_loss did not improve from 0.02971
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 466s 2s/step - accuracy: 0.8845 - loss: 0.0406 - val_accuracy: 0.8925 - val_loss: 0.0338 - learning_rate: 3.1250e-05
# Epoch 82/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8907 - loss: 0.0382
# Epoch 82: val_loss did not improve from 0.02971
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 465s 2s/step - accuracy: 0.8907 - loss: 0.0382 - val_accuracy: 0.8984 - val_loss: 0.0319 - learning_rate: 3.1250e-05
# Epoch 83/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8903 - loss: 0.0377
# Epoch 83: val_loss did not improve from 0.02971
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 466s 2s/step - accuracy: 0.8902 - loss: 0.0377 - val_accuracy: 0.8980 - val_loss: 0.0313 - learning_rate: 3.1250e-05
# Epoch 84/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8913 - loss: 0.0392
# Epoch 84: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 84: val_loss did not improve from 0.02971
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 465s 2s/step - accuracy: 0.8912 - loss: 0.0392 - val_accuracy: 0.9109 - val_loss: 0.0320 - learning_rate: 3.1250e-05
# Epoch 85/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8848 - loss: 0.0412
# Epoch 85: val_loss did not improve from 0.02971
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 466s 2s/step - accuracy: 0.8848 - loss: 0.0412 - val_accuracy: 0.9000 - val_loss: 0.0329 - learning_rate: 1.5625e-05
# Epoch 86/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8851 - loss: 0.0399
# Epoch 86: val_loss did not improve from 0.02971
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 464s 2s/step - accuracy: 0.8851 - loss: 0.0399 - val_accuracy: 0.8934 - val_loss: 0.0315 - learning_rate: 1.5625e-05
# Epoch 87/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8840 - loss: 0.0404
# Epoch 87: val_loss did not improve from 0.02971
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 463s 2s/step - accuracy: 0.8840 - loss: 0.0404 - val_accuracy: 0.8975 - val_loss: 0.0316 - learning_rate: 1.5625e-05
# Epoch 88/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8933 - loss: 0.0367
# Epoch 88: val_loss did not improve from 0.02971
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 464s 2s/step - accuracy: 0.8933 - loss: 0.0367 - val_accuracy: 0.8971 - val_loss: 0.0318 - learning_rate: 1.5625e-05
# Epoch 89/200
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8921 - loss: 0.0355
# Epoch 89: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 89: val_loss did not improve from 0.02971
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 464s 2s/step - accuracy: 0.8921 - loss: 0.0355 - val_accuracy: 0.9088 - val_loss: 0.0331 - learning_rate: 1.5625e-05
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 363 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [error  ] Error occurred during asynchronous operation processing: Cannot upload file c:\content\drive\MyDrive\Colab Notebooks\the_boss.ipynb: Path not found or is a not a file.
# [neptune] [info   ] All 363 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/lp1807/Homework1/e/HOM-377/metadata

# %%
# prompt: plot loss and accuracy on training and validation through tranining

# Plot the training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# Plot the training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# Conclusions
# If we had the chance we would have tried ConvNext, well configured for this problem.
# We would also have created a static augmented dataset to greatly reduce training time.
