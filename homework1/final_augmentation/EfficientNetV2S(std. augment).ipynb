# %% [markdown]
# This notebook is identical to EfficientNetV2S_baseline with the only difference being  we increased the free layers of the network to allow it to learn more, here we have not yet introduced augmix.
# After several tests made on the number of fine tuning layers, the best result was obtained with 400 layers. We also tried with 502 layers getting worse results online

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import neptune
from datetime import date
import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
import tensorflow as tf
import keras_cv as tfkv
from tensorflow import keras as tfk
from keras import applications
from tensorflow.keras.applications import MobileNetV2
from keras import layers as tfkl
from tensorflow.keras import mixed_precision
from io import StringIO
import os
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import to_categorical

import keras_cv

# %% [markdown]
# load the data and split on train, validation and test

# %%
data = np.load('Dataset/training_set_cleaned_NODUPLICATE.npz')
X = data['images']
y = data['labels']

# Assuming 'X' and 'y' are defined from the previous code
print("Shape of X:", X.shape)
print("Shape of y:", y.shape)
print("Number of samples:", X.shape[0])
print("Number of features:", X.shape[1:])
print("Unique labels:", np.unique(y))
# Out:
# Shape of X: (11951, 96, 96, 3)
# Shape of y: (11951, 1)
# Number of samples: 11951
# Number of features: (96, 96, 3)
# Unique labels: [0 1 2 3 4 5 6 7]

# %%
# Converting to one-hot encoding
seed = 90
y = tfk.utils.to_categorical(y,len(np.unique(y)))

# Split data into train_val and test sets
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, random_state=seed, test_size=0.1, stratify=np.argmax(y,axis=1))

# Further split train_val into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, random_state=seed, test_size=len(X_test)*2, stratify=np.argmax(y_train_val,axis=1))

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (8363, 96, 96, 3), y_train shape: (8363, 8)
# X_val shape: (2392, 96, 96, 3), y_val shape: (2392, 8)
# X_test shape: (1196, 96, 96, 3), y_test shape: (1196, 8)

# %%
def plot_class_distribution(y, title):
  num_samples = np.zeros(8)
  tmp_y = np.argmax(y, axis=1)
  for i in range(8):
    num_samples[i] = np.sum(tmp_y == i)
  plt.bar(range(8), num_samples / np.sum(num_samples))
  plt.xlabel('Class')
  plt.ylabel('Percentage')
  plt.title(title)
  plt.show()

plot_class_distribution(y_train, 'Class Distribution in Training Set')
plot_class_distribution(y_val, 'Class Distribution in Validation Set')

# %% [markdown]
# # Parameters and Hyperparameters

# %%
data_params = {
    'batch_size': 32,
    'input_shape': (96, 96, 3),
    'num_classes': 8,
    'seed': 90
}

HYPERPARAMETERS = {
    "BATCH_SIZE": 32,
    "EPOCHS": 200,
    "LEARNING_RATE": 0.001,
    "LEARNING_DESCENT_PATIENCE": 5,
    "LEARNING_DESCENT_FACTOR": 0.5,
    "EARLY_STOPPING_PATIENCE": 10,
    "DROPOUT": 0.4,
    "LAYERS_FINE_TUNE": 400,
    "MODEL_NAME": "",
    "RAND_AUGMENT_MAGNITUDE": 0.4,
    "RAND_AUGMENT_AUGMENTATIONS_PER_IMAGE": 3
}

# %% [markdown]
# # Build the model

# %% [markdown]
# ## Augmentations

# %%
AUTO = tf.data.AUTOTUNE


grid_mask = keras_cv.layers.GridMask(
      ratio_factor=(0, 0.5), rotation_factor=0.15, fill_mode="constant", fill_value=0.0)

cutout_constant = keras_cv.layers.RandomCutout(height_factor = 0.5, width_factor = 0.5, fill_mode="constant")

randomZoom = keras_cv.layers.RandomZoom(height_factor=0.5, width_factor=0.5)

hue = keras_cv.layers.RandomHue(factor=0.3, value_range=(0, 255))

channelShuffle = keras_cv.layers.ChannelShuffle(groups=3)

channelShift = keras_cv.layers.RandomChannelShift(value_range=(0, 255),factor=0.3)

simple_aug = tfk.Sequential(
    [
        tfkl.RandomFlip("horizontal"),
        tfkl.RandomRotation(factor=0.1, fill_mode = "nearest"),
        tfkl.RandomZoom(height_factor=0.1, width_factor=0.1, fill_mode = "nearest"),
    ]
)


rand_augment = tfkv.layers.RandAugment(
    value_range=(0, 255),
    augmentations_per_image=HYPERPARAMETERS['RAND_AUGMENT_AUGMENTATIONS_PER_IMAGE'],
    magnitude=HYPERPARAMETERS['RAND_AUGMENT_MAGNITUDE'],
    geometric = True
)

grid_mask_or_rand_cutout = [
    cutout_constant,
    grid_mask
]

color_trasformations = [
     hue,
     channelShuffle,
     channelShift
]


def augment(images):
  image = tf.cast(images, tf.uint8)
  images = simple_aug(image)
  images = rand_augment(images)
  images = keras_cv.layers.RandomChoice(layers=grid_mask_or_rand_cutout)(images)
  images = keras_cv.layers.RandomChoice(layers=color_trasformations)(images)

  return images

# %% [markdown]
# ## Data loaders

# %%
train_data = (
    tf.data.Dataset.from_tensor_slices((X_train, y_train))
    .shuffle(HYPERPARAMETERS['EPOCHS'] * 100)
    .batch(HYPERPARAMETERS['BATCH_SIZE'])
    .map(
        lambda x, y: (augment(x), y),
        num_parallel_calls=AUTO,
    )
    .prefetch(AUTO)
)

val_data = (
    tf.data.Dataset.from_tensor_slices((X_val, y_val))
    .batch(HYPERPARAMETERS['BATCH_SIZE'])
    .map(
        lambda x, y: (augment(x), y),
        num_parallel_calls=AUTO,
    )
    .prefetch(AUTO)
)

# %% [markdown]
# ### Plotting to see the augmentations

# %%
sample_images, _ = next(iter(train_data))
plt.figure(figsize=(10, 10))
for i, image in enumerate(sample_images[:9]):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image.numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# ## Model Definition

# %%
print('Loading model with ImageNet weights...')
MODEL_IMPORTED =tfk.applications.EfficientNetV2S(
    include_top=False,
    weights="imagenet",
    input_shape=data_params['input_shape'],
    pooling="avg",
    classes=8,
    classifier_activation="softmax",
    include_preprocessing=True,
    name="efficientnetv2-s",
)

# Set all layers in the convolutional base to Trainable (will FREEZE initial layers further below).
MODEL_IMPORTED.trainable = True

# Specify the number of layers to fine tune at the end of the convolutional base.
num_layers_fine_tune = HYPERPARAMETERS['LAYERS_FINE_TUNE']
num_layers = len(MODEL_IMPORTED.layers)

print("Num_layers fine tune " + str(num_layers_fine_tune))
print("Num_layers: " + str(num_layers))

# Freeze the initial layers in the convolutional base.
for model_layer in MODEL_IMPORTED.layers[:num_layers - num_layers_fine_tune]:
    model_layer.trainable = False

print(f"\nConfigured to fine tune the last", num_layers_fine_tune, "convolutional layers...\n")
# Out:
# Loading model with ImageNet weights...
# Num_layers fine tune 400
# Num_layers: 514
#
# Configured to fine tune the last 400 convolutional layers...

# %%
def build_model():
  """Builds the Keras model.
  """
  inputs = tf.keras.Input(shape=data_params['input_shape'])

  # Wrap the augmentation layer in a tf.function
  # Wrap augment_image in tf.py_function to execute eagerly

  x = MODEL_IMPORTED(inputs)

  x = tfkl.Dense(128, activation='relu')(x)
  x = tfkl.Dropout(HYPERPARAMETERS['DROPOUT'])(x)
  x = tfkl.Dense(64, activation='relu')(x)
  x = tfkl.Dropout(HYPERPARAMETERS['DROPOUT'])(x)


  outputs = tfkl.Dense(data_params['num_classes'], activation='softmax')(x)

  model = tfk.Model(inputs=inputs, outputs=outputs)
  print(model.summary())

  return model

# %%
model = build_model()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetv2-s (Functional)   │ (None, 1280)           │    20,331,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │           520 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,504,104 (78.22 MB)
#  Trainable params: 18,970,352 (72.37 MB)
#  Non-trainable params: 1,533,752 (5.85 MB)
# None

# %%
#model.load_weights('theboss.weights.h5')

# Costruisci il modello

model.compile(
    
    optimizer=tf.keras.optimizers.AdamW(learning_rate=HYPERPARAMETERS["LEARNING_RATE"]),
    #optimizer=tf.keras.optimizers.AdamW(learning_rate=3.125000148429535e-05),
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),
    metrics=['accuracy'],
)

# %%
# prompt: class neptune callback

run = neptune.init_run(
    project=f"lp1807/Homework1" , # Replace with your Neptune project
    api_token="API_TOKEN",
    name="EfficientNetV2S-STD_augment"
)

# Create a NeptuneCallback
class NeptuneCallback(tfk.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        run["model/train/accuracy"].log(logs["accuracy"])
        run["model/train/loss"].log(logs["loss"])
        run["model/val/accuracy"].log(logs["val_accuracy"])
        run["model/val/loss"].log(logs["val_loss"])


def saveNeptune_Drive():

  # Log the entire history dictionary to Neptune
  run["training/history"] = history.history  # <-- This line logs the entire training history

  for epoch in range(len(history.history['accuracy'])):
    run["training/epoch/train_accuracy"].log(history.history['accuracy'][epoch])
    run["training/epoch/val_accuracy"].log(history.history['val_accuracy'][epoch])
    run["training/epoch/train_loss"].log(history.history['loss'][epoch])
    run["training/epoch/val_loss"].log(history.history['val_loss'][epoch])

  model_summary = StringIO()
  model.summary(print_fn=lambda x: model_summary.write(x + "\n"))
  run["model/summary"] = model_summary.getvalue()

  # Log model weights and configuration
  run["model/weights"] = neptune.types.File.as_pickle(model.get_weights())
  run["model/config"] = model.get_config()

  model_file_path = f"StosmarmellandoConAugmentation.keras"
  model.save(model_file_path)

  # Log the .keras model file to Neptune
  run["model/file"].upload(model_file_path)

  # Convert history to DataFrame and save as CSV
  history_df = pd.DataFrame(history.history)
  history_file_path = f"StosmarmellandoConAugmentatio.csv"
  history_df.to_csv(history_file_path, index=False)

  # Log the CSV file to Neptune
  run["training/history_file"].upload(history_file_path)
  run["notebook"].upload("/content/drive/MyDrive/Colab Notebooks/the_boss.ipynb")

def saveHyperparameters():
    # Saving as Json
    run["hyperparameters"] = HYPERPARAMETERS
# Out:
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/lp1807/Homework1/e/HOM-295

# %% [markdown]
# Configuration of Neptune

# %%
# Define the checkpoint directory on Google Drive or locally
checkpoint_dir = '/checkpoints/'  # Modify this path as needed
os.makedirs(checkpoint_dir, exist_ok=True)
saveHyperparameters()

neptune_cbk = NeptuneCallback()

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=f"StosmarmellandoConAugmentationbackup.keras",
    save_weights_only=False,  # Save only model weights, not the entire model
    monitor='val_loss',      # Monitor validation loss for checkpointing
    save_best_only=True,     # Save model at the end of each epoch regardless of improvement
    save_freq = "epoch",                 # Save checkpoint every 5 epochs
    verbose=1                 # Print message when saving a checkpoint

)

# Early stopping callback
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=HYPERPARAMETERS["EARLY_STOPPING_PATIENCE"],  # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True  # Restore model weights from the epoch with the best value of the monitored quantity
)

# ReduceLROnPlateau callback to decrease the learning rate when the validation loss plateaus
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',  # Monitor validation loss
    factor=HYPERPARAMETERS["LEARNING_DESCENT_FACTOR"],  # Reduce the learning rate by a factor of 0.5
    patience=HYPERPARAMETERS["LEARNING_DESCENT_PATIENCE"],  # Number of epochs with no improvement after which learning rate will be reduced
    min_lr=1e-6,  # Lower bound on the learning rate
    verbose=1  # Print out a message when learning rate is reduced
)

# Train the model with the callbacks
history = model.fit(
    train_data,
    epochs=HYPERPARAMETERS["EPOCHS"],
    validation_data=val_data,
    callbacks=[ early_stopping, reduce_lr, checkpoint_callback]  # Include both the callbacks here
)

saveNeptune_Drive()

# Finalize the Neptune run
run.stop()
# Out:
# Epoch 1/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 644ms/step - accuracy: 0.4295 - loss: 1.5622
# Epoch 1: val_loss improved from inf to 0.71830, saving model to StosmarmellandoConAugmentationbackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 246s 728ms/step - accuracy: 0.4300 - loss: 1.5611 - val_accuracy: 0.7638 - val_loss: 0.7183 - learning_rate: 0.0010
# Epoch 2/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 652ms/step - accuracy: 0.7202 - loss: 0.8704
# Epoch 2: val_loss improved from 0.71830 to 0.59608, saving model to StosmarmellandoConAugmentationbackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 191s 721ms/step - accuracy: 0.7203 - loss: 0.8702 - val_accuracy: 0.8131 - val_loss: 0.5961 - learning_rate: 0.0010
# Epoch 3/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 696ms/step - accuracy: 0.7840 - loss: 0.7059
# Epoch 3: val_loss improved from 0.59608 to 0.40761, saving model to StosmarmellandoConAugmentationbackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 202s 765ms/step - accuracy: 0.7840 - loss: 0.7058 - val_accuracy: 0.8604 - val_loss: 0.4076 - learning_rate: 0.0010
# Epoch 4/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 649ms/step - accuracy: 0.8182 - loss: 0.5803
# Epoch 4: val_loss did not improve from 0.40761
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 188s 710ms/step - accuracy: 0.8182 - loss: 0.5803 - val_accuracy: 0.7968 - val_loss: 0.6049 - learning_rate: 0.0010
# Epoch 5/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 676ms/step - accuracy: 0.8009 - loss: 0.6560
# Epoch 5: val_loss improved from 0.40761 to 0.37535, saving model to StosmarmellandoConAugmentationbackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 197s 745ms/step - accuracy: 0.8009 - loss: 0.6558 - val_accuracy: 0.8721 - val_loss: 0.3754 - learning_rate: 0.0010
# Epoch 6/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 669ms/step - accuracy: 0.8448 - loss: 0.5271
# Epoch 6: val_loss improved from 0.37535 to 0.36987, saving model to StosmarmellandoConAugmentationbackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 195s 737ms/step - accuracy: 0.8448 - loss: 0.5270 - val_accuracy: 0.8721 - val_loss: 0.3699 - learning_rate: 0.0010
# Epoch 7/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 648ms/step - accuracy: 0.8581 - loss: 0.4623
# Epoch 7: val_loss improved from 0.36987 to 0.35081, saving model to StosmarmellandoConAugmentationbackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 189s 715ms/step - accuracy: 0.8580 - loss: 0.4623 - val_accuracy: 0.8754 - val_loss: 0.3508 - learning_rate: 0.0010
# Epoch 8/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 652ms/step - accuracy: 0.8523 - loss: 0.4769
# Epoch 8: val_loss improved from 0.35081 to 0.33495, saving model to StosmarmellandoConAugmentationbackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 190s 719ms/step - accuracy: 0.8524 - loss: 0.4768 - val_accuracy: 0.8846 - val_loss: 0.3349 - learning_rate: 0.0010
# Epoch 9/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 651ms/step - accuracy: 0.8664 - loss: 0.4317
# Epoch 9: val_loss improved from 0.33495 to 0.32282, saving model to StosmarmellandoConAugmentationbackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 190s 718ms/step - accuracy: 0.8664 - loss: 0.4317 - val_accuracy: 0.8913 - val_loss: 0.3228 - learning_rate: 0.0010
# Epoch 10/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 647ms/step - accuracy: 0.8699 - loss: 0.4086
# Epoch 10: val_loss improved from 0.32282 to 0.30802, saving model to StosmarmellandoConAugmentationbackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 189s 714ms/step - accuracy: 0.8699 - loss: 0.4086 - val_accuracy: 0.8926 - val_loss: 0.3080 - learning_rate: 0.0010
# Epoch 11/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 652ms/step - accuracy: 0.8738 - loss: 0.4001
# Epoch 11: val_loss did not improve from 0.30802
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 188s 712ms/step - accuracy: 0.8738 - loss: 0.4001 - val_accuracy: 0.8763 - val_loss: 0.3889 - learning_rate: 0.0010
# Epoch 12/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 654ms/step - accuracy: 0.8744 - loss: 0.4066
# Epoch 12: val_loss improved from 0.30802 to 0.27654, saving model to StosmarmellandoConAugmentationbackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 191s 723ms/step - accuracy: 0.8744 - loss: 0.4065 - val_accuracy: 0.9051 - val_loss: 0.2765 - learning_rate: 0.0010
# Epoch 13/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 667ms/step - accuracy: 0.8794 - loss: 0.3770
# Epoch 13: val_loss improved from 0.27654 to 0.26246, saving model to StosmarmellandoConAugmentationbackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 196s 741ms/step - accuracy: 0.8794 - loss: 0.3770 - val_accuracy: 0.9076 - val_loss: 0.2625 - learning_rate: 0.0010
# Epoch 14/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 668ms/step - accuracy: 0.8781 - loss: 0.3918
# Epoch 14: val_loss did not improve from 0.26246
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 192s 727ms/step - accuracy: 0.8781 - loss: 0.3917 - val_accuracy: 0.8976 - val_loss: 0.2960 - learning_rate: 0.0010
# Epoch 15/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 652ms/step - accuracy: 0.8801 - loss: 0.3862
# Epoch 15: val_loss did not improve from 0.26246
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 188s 712ms/step - accuracy: 0.8801 - loss: 0.3862 - val_accuracy: 0.9022 - val_loss: 0.2893 - learning_rate: 0.0010
# Epoch 16/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 651ms/step - accuracy: 0.8841 - loss: 0.3595
# Epoch 16: val_loss improved from 0.26246 to 0.24396, saving model to StosmarmellandoConAugmentationbackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 190s 718ms/step - accuracy: 0.8841 - loss: 0.3595 - val_accuracy: 0.9239 - val_loss: 0.2440 - learning_rate: 0.0010
# Epoch 17/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 650ms/step - accuracy: 0.8828 - loss: 0.3837
# Epoch 17: val_loss did not improve from 0.24396
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 188s 710ms/step - accuracy: 0.8828 - loss: 0.3836 - val_accuracy: 0.9059 - val_loss: 0.2771 - learning_rate: 0.0010
# Epoch 18/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 647ms/step - accuracy: 0.8849 - loss: 0.3669
# Epoch 18: val_loss did not improve from 0.24396
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 187s 707ms/step - accuracy: 0.8849 - loss: 0.3668 - val_accuracy: 0.8909 - val_loss: 0.3362 - learning_rate: 0.0010
# Epoch 19/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 652ms/step - accuracy: 0.8866 - loss: 0.3599
# Epoch 19: val_loss did not improve from 0.24396
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 188s 712ms/step - accuracy: 0.8866 - loss: 0.3599 - val_accuracy: 0.9089 - val_loss: 0.2770 - learning_rate: 0.0010
# Epoch 20/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 649ms/step - accuracy: 0.8939 - loss: 0.3415
# Epoch 20: val_loss did not improve from 0.24396
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 187s 709ms/step - accuracy: 0.8938 - loss: 0.3415 - val_accuracy: 0.9168 - val_loss: 0.2497 - learning_rate: 0.0010
# Epoch 21/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 650ms/step - accuracy: 0.8941 - loss: 0.3384
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 21: val_loss did not improve from 0.24396
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 188s 710ms/step - accuracy: 0.8941 - loss: 0.3384 - val_accuracy: 0.8951 - val_loss: 0.2964 - learning_rate: 0.0010
# Epoch 22/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 652ms/step - accuracy: 0.9011 - loss: 0.3024
# Epoch 22: val_loss improved from 0.24396 to 0.19927, saving model to StosmarmellandoConAugmentationbackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 190s 718ms/step - accuracy: 0.9012 - loss: 0.3024 - val_accuracy: 0.9260 - val_loss: 0.1993 - learning_rate: 5.0000e-04
# Epoch 23/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 651ms/step - accuracy: 0.9125 - loss: 0.2809
# Epoch 23: val_loss did not improve from 0.19927
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 188s 711ms/step - accuracy: 0.9125 - loss: 0.2809 - val_accuracy: 0.9327 - val_loss: 0.2011 - learning_rate: 5.0000e-04
# Epoch 24/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 649ms/step - accuracy: 0.9129 - loss: 0.2748
# Epoch 24: val_loss did not improve from 0.19927
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 187s 709ms/step - accuracy: 0.9129 - loss: 0.2748 - val_accuracy: 0.9273 - val_loss: 0.2126 - learning_rate: 5.0000e-04
# Epoch 25/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 649ms/step - accuracy: 0.9167 - loss: 0.2871
# Epoch 25: val_loss did not improve from 0.19927
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 188s 709ms/step - accuracy: 0.9167 - loss: 0.2871 - val_accuracy: 0.9277 - val_loss: 0.2128 - learning_rate: 5.0000e-04
# Epoch 26/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 658ms/step - accuracy: 0.9188 - loss: 0.2631
# Epoch 26: val_loss did not improve from 0.19927
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 192s 726ms/step - accuracy: 0.9189 - loss: 0.2630 - val_accuracy: 0.9360 - val_loss: 0.2085 - learning_rate: 5.0000e-04
# Epoch 27/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 696ms/step - accuracy: 0.9104 - loss: 0.2746
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 27: val_loss did not improve from 0.19927
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 202s 762ms/step - accuracy: 0.9104 - loss: 0.2746 - val_accuracy: 0.9314 - val_loss: 0.2082 - learning_rate: 5.0000e-04
# Epoch 28/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 699ms/step - accuracy: 0.9159 - loss: 0.2519
# Epoch 28: val_loss improved from 0.19927 to 0.19150, saving model to StosmarmellandoConAugmentationbackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 204s 772ms/step - accuracy: 0.9159 - loss: 0.2518 - val_accuracy: 0.9390 - val_loss: 0.1915 - learning_rate: 2.5000e-04
# Epoch 29/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 693ms/step - accuracy: 0.9258 - loss: 0.2204
# Epoch 29: val_loss did not improve from 0.19150
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 201s 758ms/step - accuracy: 0.9258 - loss: 0.2204 - val_accuracy: 0.9356 - val_loss: 0.1969 - learning_rate: 2.5000e-04
# Epoch 30/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 695ms/step - accuracy: 0.9349 - loss: 0.2156
# Epoch 30: val_loss did not improve from 0.19150
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 201s 761ms/step - accuracy: 0.9349 - loss: 0.2156 - val_accuracy: 0.9344 - val_loss: 0.1932 - learning_rate: 2.5000e-04
# Epoch 31/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 696ms/step - accuracy: 0.9217 - loss: 0.2345
# Epoch 31: val_loss improved from 0.19150 to 0.18723, saving model to StosmarmellandoConAugmentationbackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 204s 772ms/step - accuracy: 0.9217 - loss: 0.2345 - val_accuracy: 0.9323 - val_loss: 0.1872 - learning_rate: 2.5000e-04
# Epoch 32/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 694ms/step - accuracy: 0.9278 - loss: 0.2171
# Epoch 32: val_loss improved from 0.18723 to 0.16729, saving model to StosmarmellandoConAugmentationbackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 203s 768ms/step - accuracy: 0.9278 - loss: 0.2171 - val_accuracy: 0.9444 - val_loss: 0.1673 - learning_rate: 2.5000e-04
# Epoch 33/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 693ms/step - accuracy: 0.9381 - loss: 0.2083
# Epoch 33: val_loss did not improve from 0.16729
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 201s 759ms/step - accuracy: 0.9381 - loss: 0.2083 - val_accuracy: 0.9373 - val_loss: 0.1834 - learning_rate: 2.5000e-04
# Epoch 34/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 666ms/step - accuracy: 0.9359 - loss: 0.2118
# Epoch 34: val_loss did not improve from 0.16729
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 192s 727ms/step - accuracy: 0.9359 - loss: 0.2119 - val_accuracy: 0.9314 - val_loss: 0.1956 - learning_rate: 2.5000e-04
# Epoch 35/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 649ms/step - accuracy: 0.9400 - loss: 0.2001
# Epoch 35: val_loss improved from 0.16729 to 0.15141, saving model to StosmarmellandoConAugmentationbackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 189s 716ms/step - accuracy: 0.9400 - loss: 0.2002 - val_accuracy: 0.9469 - val_loss: 0.1514 - learning_rate: 2.5000e-04
# Epoch 36/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 653ms/step - accuracy: 0.9330 - loss: 0.2095
# Epoch 36: val_loss did not improve from 0.15141
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 189s 713ms/step - accuracy: 0.9331 - loss: 0.2095 - val_accuracy: 0.9444 - val_loss: 0.1782 - learning_rate: 2.5000e-04
# Epoch 37/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 654ms/step - accuracy: 0.9355 - loss: 0.2009
# Epoch 37: val_loss did not improve from 0.15141
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 189s 714ms/step - accuracy: 0.9355 - loss: 0.2009 - val_accuracy: 0.9335 - val_loss: 0.1988 - learning_rate: 2.5000e-04
# Epoch 38/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 653ms/step - accuracy: 0.9364 - loss: 0.1973
# Epoch 38: val_loss did not improve from 0.15141
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 189s 715ms/step - accuracy: 0.9364 - loss: 0.1973 - val_accuracy: 0.9448 - val_loss: 0.1635 - learning_rate: 2.5000e-04
# Epoch 39/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 655ms/step - accuracy: 0.9381 - loss: 0.2100
# Epoch 39: val_loss did not improve from 0.15141
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 189s 715ms/step - accuracy: 0.9381 - loss: 0.2100 - val_accuracy: 0.9503 - val_loss: 0.1562 - learning_rate: 2.5000e-04
# Epoch 40/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 651ms/step - accuracy: 0.9395 - loss: 0.1871
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 40: val_loss did not improve from 0.15141
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 188s 711ms/step - accuracy: 0.9395 - loss: 0.1871 - val_accuracy: 0.9423 - val_loss: 0.1531 - learning_rate: 2.5000e-04
# Epoch 41/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 653ms/step - accuracy: 0.9355 - loss: 0.2076
# Epoch 41: val_loss did not improve from 0.15141
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 189s 713ms/step - accuracy: 0.9355 - loss: 0.2076 - val_accuracy: 0.9457 - val_loss: 0.1707 - learning_rate: 1.2500e-04
# Epoch 42/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 653ms/step - accuracy: 0.9434 - loss: 0.1795
# Epoch 42: val_loss did not improve from 0.15141
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 189s 713ms/step - accuracy: 0.9434 - loss: 0.1795 - val_accuracy: 0.9431 - val_loss: 0.1611 - learning_rate: 1.2500e-04
# Epoch 43/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 652ms/step - accuracy: 0.9468 - loss: 0.1586
# Epoch 43: val_loss did not improve from 0.15141
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 188s 713ms/step - accuracy: 0.9468 - loss: 0.1586 - val_accuracy: 0.9473 - val_loss: 0.1691 - learning_rate: 1.2500e-04
# Epoch 44/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 655ms/step - accuracy: 0.9399 - loss: 0.1842
# Epoch 44: val_loss did not improve from 0.15141
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 190s 717ms/step - accuracy: 0.9399 - loss: 0.1842 - val_accuracy: 0.9457 - val_loss: 0.1609 - learning_rate: 1.2500e-04
# Epoch 45/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 655ms/step - accuracy: 0.9399 - loss: 0.1787
# Epoch 45: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 45: val_loss did not improve from 0.15141
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 189s 715ms/step - accuracy: 0.9399 - loss: 0.1787 - val_accuracy: 0.9498 - val_loss: 0.1548 - learning_rate: 1.2500e-04
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 187 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [error  ] Error occurred during asynchronous operation processing: Cannot upload file c:\content\drive\MyDrive\Colab Notebooks\the_boss.ipynb: Path not found or is a not a file.
# [neptune] [info   ] All 187 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/lp1807/Homework1/e/HOM-295/metadata

# %%
# prompt: plot loss and accuracy on training and validation through tranining

# Plot the training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# Plot the training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()
