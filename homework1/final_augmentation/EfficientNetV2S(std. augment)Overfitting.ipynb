# %% [markdown]
# Here we find the exact same test as EfficientNetV2S(std. augment) with 502 layers, which gave worse online performance

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import neptune
from datetime import date
import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
import tensorflow as tf
import keras_cv as tfkv
from tensorflow import keras as tfk
from keras import applications
from tensorflow.keras.applications import MobileNetV2
from keras import layers as tfkl
from tensorflow.keras import mixed_precision
from io import StringIO
import os
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import to_categorical

import keras_cv

# %% [markdown]
# load the data and split on train, validation and test

# %%
data = np.load('Dataset/training_set_cleaned_NODUPLICATE.npz')
X = data['images']
y = data['labels']

# Assuming 'X' and 'y' are defined from the previous code
print("Shape of X:", X.shape)
print("Shape of y:", y.shape)
print("Number of samples:", X.shape[0])
print("Number of features:", X.shape[1:])
print("Unique labels:", np.unique(y))
# Out:
# Shape of X: (11951, 96, 96, 3)
# Shape of y: (11951, 1)
# Number of samples: 11951
# Number of features: (96, 96, 3)
# Unique labels: [0 1 2 3 4 5 6 7]

# %%
# Converting to one-hot encoding
seed = 90
y = tfk.utils.to_categorical(y,len(np.unique(y)))

# Split data into train_val and test sets
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, random_state=seed, test_size=0.1, stratify=np.argmax(y,axis=1))

# Further split train_val into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, random_state=seed, test_size=len(X_test)*2, stratify=np.argmax(y_train_val,axis=1))

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (8363, 96, 96, 3), y_train shape: (8363, 8)
# X_val shape: (2392, 96, 96, 3), y_val shape: (2392, 8)
# X_test shape: (1196, 96, 96, 3), y_test shape: (1196, 8)

# %%
def plot_class_distribution(y, title):
  num_samples = np.zeros(8)
  tmp_y = np.argmax(y, axis=1)
  for i in range(8):
    num_samples[i] = np.sum(tmp_y == i)
  plt.bar(range(8), num_samples / np.sum(num_samples))
  plt.xlabel('Class')
  plt.ylabel('Percentage')
  plt.title(title)
  plt.show()

plot_class_distribution(y_train, 'Class Distribution in Training Set')
plot_class_distribution(y_val, 'Class Distribution in Validation Set')

# %% [markdown]
# # Parameters and Hyperparameters

# %%
data_params = {
    'batch_size': 32,
    'input_shape': (96, 96, 3),
    'num_classes': 8,
    'seed': 90
}

HYPERPARAMETERS = {
    "BATCH_SIZE": 32,
    "EPOCHS": 200,
    "LEARNING_RATE": 0.001,
    "LEARNING_DESCENT_PATIENCE": 5,
    "LEARNING_DESCENT_FACTOR": 0.5,
    "EARLY_STOPPING_PATIENCE": 10,
    "DROPOUT": 0.4,
    "LAYERS_FINE_TUNE": 514 - 12,
    "MODEL_NAME": "",
    "RAND_AUGMENT_MAGNITUDE": 0.4,
    "RAND_AUGMENT_AUGMENTATIONS_PER_IMAGE": 2
}

# %% [markdown]
# # Build the model

# %% [markdown]
# ## Augmentations

# %%
AUTO = tf.data.AUTOTUNE


grid_mask = keras_cv.layers.GridMask(
      ratio_factor=(0, 0.5), rotation_factor=0.15, fill_mode="constant", fill_value=0.0)

cutout_constant = keras_cv.layers.RandomCutout(height_factor = 0.5, width_factor = 0.5, fill_mode="constant")

randomZoom = keras_cv.layers.RandomZoom(height_factor=0.5, width_factor=0.5)

hue = keras_cv.layers.RandomHue(factor=0.3, value_range=(0, 255))

channelShuffle = keras_cv.layers.ChannelShuffle(groups=3)

channelShift = keras_cv.layers.RandomChannelShift(value_range=(0, 255),factor=0.3)

simple_aug = tfk.Sequential(
    [
        tfkl.RandomFlip("horizontal"),
        tfkl.RandomRotation(factor=0.1, fill_mode = "nearest"),
        tfkl.RandomZoom(height_factor=0.1, width_factor=0.1, fill_mode = "nearest"),
    ]
)


rand_augment = tfkv.layers.RandAugment(
    value_range=(0, 255),
    augmentations_per_image=HYPERPARAMETERS['RAND_AUGMENT_AUGMENTATIONS_PER_IMAGE'],
    magnitude=HYPERPARAMETERS['RAND_AUGMENT_MAGNITUDE'],
    geometric = True
)

grid_mask_or_rand_cutout = [
    cutout_constant,
    grid_mask
]

color_trasformations = [
     hue,
     channelShuffle,
     channelShift
]


def augment(images):
  image = tf.cast(images, tf.uint8)
  images = simple_aug(image)
  images = rand_augment(images)
  images = keras_cv.layers.RandomChoice(layers=grid_mask_or_rand_cutout)(images)
  images = keras_cv.layers.RandomChoice(layers=color_trasformations)(images)

  return images

# %% [markdown]
# ## Data loaders

# %%
train_data = (
    tf.data.Dataset.from_tensor_slices((X_train, y_train))
    .shuffle(HYPERPARAMETERS['EPOCHS'] * 100)
    .batch(HYPERPARAMETERS['BATCH_SIZE'])
    .map(
        lambda x, y: (augment(x), y),
        num_parallel_calls=AUTO,
    )
    .prefetch(AUTO)
)

val_data = (
    tf.data.Dataset.from_tensor_slices((X_val, y_val))
    .batch(HYPERPARAMETERS['BATCH_SIZE'])
    .map(
        lambda x, y: (augment(x), y),
        num_parallel_calls=AUTO,
    )
    .prefetch(AUTO)
)

# %% [markdown]
# ### Plotting to see the augmentations

# %%
sample_images, _ = next(iter(train_data))
plt.figure(figsize=(10, 10))
for i, image in enumerate(sample_images[:9]):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image.numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# ## Model Definition

# %%
print('Loading model with ImageNet weights...')
MODEL_IMPORTED =tfk.applications.EfficientNetV2S(
    include_top=False,
    weights="imagenet",
    input_shape=data_params['input_shape'],
    pooling="avg",
    classes=8,
    classifier_activation="softmax",
    include_preprocessing=True,
    name="efficientnetv2-s",
)

# Set all layers in the convolutional base to Trainable (will FREEZE initial layers further below).
MODEL_IMPORTED.trainable = True

# Specify the number of layers to fine tune at the end of the convolutional base.
num_layers_fine_tune = HYPERPARAMETERS['LAYERS_FINE_TUNE']
num_layers = len(MODEL_IMPORTED.layers)

print("Num_layers fine tune " + str(num_layers_fine_tune))
print("Num_layers: " + str(num_layers))

# Freeze the initial layers in the convolutional base.
for model_layer in MODEL_IMPORTED.layers[:num_layers - num_layers_fine_tune]:
    model_layer.trainable = False

print(f"\nConfigured to fine tune the last", num_layers_fine_tune, "convolutional layers...\n")
# Out:
# Loading model with ImageNet weights...
# Num_layers fine tune 502
# Num_layers: 514
#
# Configured to fine tune the last 502 convolutional layers...

# %%
def build_model():
  """Builds the Keras model.
  """
  inputs = tf.keras.Input(shape=data_params['input_shape'])

  # Wrap the augmentation layer in a tf.function
  # Wrap augment_image in tf.py_function to execute eagerly

  x = MODEL_IMPORTED(inputs)

  x = tfkl.Dense(128, activation='relu')(x)
  x = tfkl.Dropout(HYPERPARAMETERS['DROPOUT'])(x)
  x = tfkl.Dense(64, activation='relu')(x)
  x = tfkl.Dropout(HYPERPARAMETERS['DROPOUT'])(x)


  outputs = tfkl.Dense(data_params['num_classes'], activation='softmax')(x)

  model = tfk.Model(inputs=inputs, outputs=outputs)
  print(model.summary())

  return model

# %%
model = build_model()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetv2-s (Functional)   │ (None, 1280)           │    20,331,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │           520 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,504,104 (78.22 MB)
#  Trainable params: 20,339,072 (77.59 MB)
#  Non-trainable params: 165,032 (644.66 KB)
# None

# %% [markdown]
# Configuration of Neptune

# %%
model.compile(
    
    optimizer=tf.keras.optimizers.AdamW(learning_rate=HYPERPARAMETERS["LEARNING_RATE"]),
    #optimizer=tf.keras.optimizers.AdamW(learning_rate=3.125000148429535e-05),
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),
    metrics=['accuracy'],
)

# %%
# prompt: class neptune callback

run = neptune.init_run(
    project=f"lp1807/Homework1" , # Replace with your Neptune project
    api_token="API_TOKEN",
    name="EfficientNetV2S-std_augment"
)

# Create a NeptuneCallback
class NeptuneCallback(tfk.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        run["model/train/accuracy"].log(logs["accuracy"])
        run["model/train/loss"].log(logs["loss"])
        run["model/val/accuracy"].log(logs["val_accuracy"])
        run["model/val/loss"].log(logs["val_loss"])


def saveNeptune_Drive():

  # Log the entire history dictionary to Neptune
  run["training/history"] = history.history  # <-- This line logs the entire training history

  for epoch in range(len(history.history['accuracy'])):
    run["training/epoch/train_accuracy"].log(history.history['accuracy'][epoch])
    run["training/epoch/val_accuracy"].log(history.history['val_accuracy'][epoch])
    run["training/epoch/train_loss"].log(history.history['loss'][epoch])
    run["training/epoch/val_loss"].log(history.history['val_loss'][epoch])

  model_summary = StringIO()
  model.summary(print_fn=lambda x: model_summary.write(x + "\n"))
  run["model/summary"] = model_summary.getvalue()

  # Log model weights and configuration
  run["model/weights"] = neptune.types.File.as_pickle(model.get_weights())
  run["model/config"] = model.get_config()

  model_file_path = f"ApriTuttoDuccio.keras"
  model.save(model_file_path)

  # Log the .keras model file to Neptune
  run["model/file"].upload(model_file_path)

  # Convert history to DataFrame and save as CSV
  history_df = pd.DataFrame(history.history)
  history_file_path = f"ApriTuttoDuccio.csv"
  history_df.to_csv(history_file_path, index=False)

  # Log the CSV file to Neptune
  run["training/history_file"].upload(history_file_path)
  run["notebook"].upload("/content/drive/MyDrive/Colab Notebooks/the_boss.ipynb")

def saveHyperparameters():
    # Saving as Json
    run["hyperparameters"] = HYPERPARAMETERS
# Out:
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/lp1807/Homework1/e/HOM-287

# %%
# Define the checkpoint directory on Google Drive or locally
checkpoint_dir = '/checkpoints/'  # Modify this path as needed
os.makedirs(checkpoint_dir, exist_ok=True)
saveHyperparameters()

neptune_cbk = NeptuneCallback()

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=f"ApriTuttoDucciobackup.keras",
    save_weights_only=False,  # Save only model weights, not the entire model
    monitor='val_loss',      # Monitor validation loss for checkpointing
    save_best_only=True,     # Save model at the end of each epoch regardless of improvement
    save_freq = "epoch",                 # Save checkpoint every 5 epochs
    verbose=1                 # Print message when saving a checkpoint

)

# Early stopping callback
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=HYPERPARAMETERS["EARLY_STOPPING_PATIENCE"],  # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True  # Restore model weights from the epoch with the best value of the monitored quantity
)

# ReduceLROnPlateau callback to decrease the learning rate when the validation loss plateaus
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',  # Monitor validation loss
    factor=HYPERPARAMETERS["LEARNING_DESCENT_FACTOR"],  # Reduce the learning rate by a factor of 0.5
    patience=HYPERPARAMETERS["LEARNING_DESCENT_PATIENCE"],  # Number of epochs with no improvement after which learning rate will be reduced
    min_lr=1e-6,  # Lower bound on the learning rate
    verbose=1  # Print out a message when learning rate is reduced
)

# Train the model with the callbacks
history = model.fit(
    train_data,
    epochs=HYPERPARAMETERS["EPOCHS"],
    validation_data=val_data,
    callbacks=[ early_stopping, reduce_lr, checkpoint_callback]  # Include both the callbacks here
)

saveNeptune_Drive()

# Finalize the Neptune run
run.stop()
# Out:
# Epoch 1/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 959ms/step - accuracy: 0.4550 - loss: 1.5052
# Epoch 1: val_loss improved from inf to 0.73332, saving model to ApriTuttoDucciobackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 345s 1s/step - accuracy: 0.4555 - loss: 1.5040 - val_accuracy: 0.7458 - val_loss: 0.7333 - learning_rate: 0.0010
# Epoch 2/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 977ms/step - accuracy: 0.7361 - loss: 0.8245
# Epoch 2: val_loss improved from 0.73332 to 0.44237, saving model to ApriTuttoDucciobackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 278s 1s/step - accuracy: 0.7362 - loss: 0.8243 - val_accuracy: 0.8457 - val_loss: 0.4424 - learning_rate: 0.0010
# Epoch 3/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 978ms/step - accuracy: 0.8002 - loss: 0.6646
# Epoch 3: val_loss did not improve from 0.44237
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 275s 1s/step - accuracy: 0.8003 - loss: 0.6645 - val_accuracy: 0.8449 - val_loss: 0.4729 - learning_rate: 0.0010
# Epoch 4/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 971ms/step - accuracy: 0.8261 - loss: 0.5759
# Epoch 4: val_loss improved from 0.44237 to 0.34055, saving model to ApriTuttoDucciobackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 276s 1s/step - accuracy: 0.8261 - loss: 0.5759 - val_accuracy: 0.8938 - val_loss: 0.3406 - learning_rate: 0.0010
# Epoch 5/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 974ms/step - accuracy: 0.8516 - loss: 0.4993
# Epoch 5: val_loss did not improve from 0.34055
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 274s 1s/step - accuracy: 0.8516 - loss: 0.4993 - val_accuracy: 0.8817 - val_loss: 0.3590 - learning_rate: 0.0010
# Epoch 6/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 970ms/step - accuracy: 0.8474 - loss: 0.4741
# Epoch 6: val_loss improved from 0.34055 to 0.33020, saving model to ApriTuttoDucciobackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 275s 1s/step - accuracy: 0.8474 - loss: 0.4741 - val_accuracy: 0.8926 - val_loss: 0.3302 - learning_rate: 0.0010
# Epoch 7/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 976ms/step - accuracy: 0.8097 - loss: 0.5899
# Epoch 7: val_loss did not improve from 0.33020
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 274s 1s/step - accuracy: 0.8097 - loss: 0.5900 - val_accuracy: 0.8779 - val_loss: 0.3868 - learning_rate: 0.0010
# Epoch 8/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 974ms/step - accuracy: 0.8611 - loss: 0.4507
# Epoch 8: val_loss did not improve from 0.33020
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 274s 1s/step - accuracy: 0.8611 - loss: 0.4507 - val_accuracy: 0.8792 - val_loss: 0.3622 - learning_rate: 0.0010
# Epoch 9/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 965ms/step - accuracy: 0.8675 - loss: 0.4264
# Epoch 9: val_loss did not improve from 0.33020
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 271s 1s/step - accuracy: 0.8675 - loss: 0.4263 - val_accuracy: 0.8855 - val_loss: 0.3499 - learning_rate: 0.0010
# Epoch 10/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 971ms/step - accuracy: 0.8308 - loss: 0.5446
# Epoch 10: val_loss improved from 0.33020 to 0.30426, saving model to ApriTuttoDucciobackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 277s 1s/step - accuracy: 0.8309 - loss: 0.5444 - val_accuracy: 0.8967 - val_loss: 0.3043 - learning_rate: 0.0010
# Epoch 11/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 972ms/step - accuracy: 0.8790 - loss: 0.4060
# Epoch 11: val_loss improved from 0.30426 to 0.27785, saving model to ApriTuttoDucciobackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 276s 1s/step - accuracy: 0.8790 - loss: 0.4059 - val_accuracy: 0.9084 - val_loss: 0.2778 - learning_rate: 0.0010
# Epoch 12/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 983ms/step - accuracy: 0.8833 - loss: 0.3862
# Epoch 12: val_loss did not improve from 0.27785
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 276s 1s/step - accuracy: 0.8833 - loss: 0.3862 - val_accuracy: 0.9043 - val_loss: 0.2804 - learning_rate: 0.0010
# Epoch 13/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 964ms/step - accuracy: 0.8854 - loss: 0.3711
# Epoch 13: val_loss improved from 0.27785 to 0.26792, saving model to ApriTuttoDucciobackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 273s 1s/step - accuracy: 0.8854 - loss: 0.3711 - val_accuracy: 0.9118 - val_loss: 0.2679 - learning_rate: 0.0010
# Epoch 14/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 962ms/step - accuracy: 0.8745 - loss: 0.4142
# Epoch 14: val_loss did not improve from 0.26792
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 271s 1s/step - accuracy: 0.8745 - loss: 0.4140 - val_accuracy: 0.9089 - val_loss: 0.4186 - learning_rate: 0.0010
# Epoch 15/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 961ms/step - accuracy: 0.8932 - loss: 0.3492
# Epoch 15: val_loss did not improve from 0.26792
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 270s 1s/step - accuracy: 0.8932 - loss: 0.3492 - val_accuracy: 0.9026 - val_loss: 0.2946 - learning_rate: 0.0010
# Epoch 16/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 961ms/step - accuracy: 0.8959 - loss: 0.3395
# Epoch 16: val_loss did not improve from 0.26792
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 270s 1s/step - accuracy: 0.8959 - loss: 0.3395 - val_accuracy: 0.9005 - val_loss: 0.3055 - learning_rate: 0.0010
# Epoch 17/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 977ms/step - accuracy: 0.8939 - loss: 0.3443
# Epoch 17: val_loss improved from 0.26792 to 0.25187, saving model to ApriTuttoDucciobackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 278s 1s/step - accuracy: 0.8939 - loss: 0.3443 - val_accuracy: 0.9143 - val_loss: 0.2519 - learning_rate: 0.0010
# Epoch 18/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 977ms/step - accuracy: 0.9034 - loss: 0.3109
# Epoch 18: val_loss did not improve from 0.25187
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 274s 1s/step - accuracy: 0.9034 - loss: 0.3109 - val_accuracy: 0.9114 - val_loss: 0.2645 - learning_rate: 0.0010
# Epoch 19/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 961ms/step - accuracy: 0.9055 - loss: 0.3090
# Epoch 19: val_loss did not improve from 0.25187
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 271s 1s/step - accuracy: 0.9055 - loss: 0.3090 - val_accuracy: 0.9043 - val_loss: 0.3273 - learning_rate: 0.0010
# Epoch 20/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 973ms/step - accuracy: 0.9088 - loss: 0.3037
# Epoch 20: val_loss improved from 0.25187 to 0.22945, saving model to ApriTuttoDucciobackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 276s 1s/step - accuracy: 0.9088 - loss: 0.3037 - val_accuracy: 0.9231 - val_loss: 0.2295 - learning_rate: 0.0010
# Epoch 21/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 932ms/step - accuracy: 0.9005 - loss: 0.3182
# Epoch 21: val_loss did not improve from 0.22945
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 262s 992ms/step - accuracy: 0.9005 - loss: 0.3181 - val_accuracy: 0.9093 - val_loss: 0.2808 - learning_rate: 0.0010
# Epoch 22/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 919ms/step - accuracy: 0.9024 - loss: 0.3012
# Epoch 22: val_loss did not improve from 0.22945
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 258s 979ms/step - accuracy: 0.9024 - loss: 0.3012 - val_accuracy: 0.9130 - val_loss: 0.2419 - learning_rate: 0.0010
# Epoch 23/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 917ms/step - accuracy: 0.9123 - loss: 0.2791
# Epoch 23: val_loss improved from 0.22945 to 0.22490, saving model to ApriTuttoDucciobackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 260s 986ms/step - accuracy: 0.9123 - loss: 0.2792 - val_accuracy: 0.9218 - val_loss: 0.2249 - learning_rate: 0.0010
# Epoch 24/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 951ms/step - accuracy: 0.9078 - loss: 0.2925
# Epoch 24: val_loss did not improve from 0.22490
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 268s 1s/step - accuracy: 0.9078 - loss: 0.2925 - val_accuracy: 0.8988 - val_loss: 0.2878 - learning_rate: 0.0010
# Epoch 25/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 966ms/step - accuracy: 0.9149 - loss: 0.2839
# Epoch 25: val_loss did not improve from 0.22490
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 272s 1s/step - accuracy: 0.9148 - loss: 0.2839 - val_accuracy: 0.9206 - val_loss: 0.2434 - learning_rate: 0.0010
# Epoch 26/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 967ms/step - accuracy: 0.9107 - loss: 0.2838
# Epoch 26: val_loss did not improve from 0.22490
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 272s 1s/step - accuracy: 0.9106 - loss: 0.2839 - val_accuracy: 0.9235 - val_loss: 0.2655 - learning_rate: 0.0010
# Epoch 27/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 965ms/step - accuracy: 0.9124 - loss: 0.2801
# Epoch 27: val_loss improved from 0.22490 to 0.22251, saving model to ApriTuttoDucciobackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 274s 1s/step - accuracy: 0.9124 - loss: 0.2802 - val_accuracy: 0.9289 - val_loss: 0.2225 - learning_rate: 0.0010
# Epoch 28/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 974ms/step - accuracy: 0.9136 - loss: 0.2836
# Epoch 28: val_loss did not improve from 0.22251
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 274s 1s/step - accuracy: 0.9136 - loss: 0.2837 - val_accuracy: 0.9197 - val_loss: 0.3384 - learning_rate: 0.0010
# Epoch 29/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 965ms/step - accuracy: 0.9138 - loss: 0.2805
# Epoch 29: val_loss did not improve from 0.22251
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 270s 1s/step - accuracy: 0.9137 - loss: 0.2805 - val_accuracy: 0.9168 - val_loss: 0.3017 - learning_rate: 0.0010
# Epoch 30/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 933ms/step - accuracy: 0.9199 - loss: 0.2408
# Epoch 30: val_loss did not improve from 0.22251
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 263s 998ms/step - accuracy: 0.9199 - loss: 0.2408 - val_accuracy: 0.9260 - val_loss: 0.2292 - learning_rate: 0.0010
# Epoch 31/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 968ms/step - accuracy: 0.9179 - loss: 0.2636
# Epoch 31: val_loss did not improve from 0.22251
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 272s 1s/step - accuracy: 0.9179 - loss: 0.2636 - val_accuracy: 0.9202 - val_loss: 0.2555 - learning_rate: 0.0010
# Epoch 32/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 965ms/step - accuracy: 0.9116 - loss: 0.2837
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 32: val_loss did not improve from 0.22251
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 272s 1s/step - accuracy: 0.9117 - loss: 0.2837 - val_accuracy: 0.9156 - val_loss: 0.2677 - learning_rate: 0.0010
# Epoch 33/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 966ms/step - accuracy: 0.9169 - loss: 0.2523
# Epoch 33: val_loss improved from 0.22251 to 0.17357, saving model to ApriTuttoDucciobackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 274s 1s/step - accuracy: 0.9169 - loss: 0.2522 - val_accuracy: 0.9411 - val_loss: 0.1736 - learning_rate: 5.0000e-04
# Epoch 34/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 967ms/step - accuracy: 0.9379 - loss: 0.2002
# Epoch 34: val_loss improved from 0.17357 to 0.17046, saving model to ApriTuttoDucciobackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 274s 1s/step - accuracy: 0.9379 - loss: 0.2002 - val_accuracy: 0.9431 - val_loss: 0.1705 - learning_rate: 5.0000e-04
# Epoch 35/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 976ms/step - accuracy: 0.9416 - loss: 0.1833
# Epoch 35: val_loss did not improve from 0.17046
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 275s 1s/step - accuracy: 0.9416 - loss: 0.1833 - val_accuracy: 0.9289 - val_loss: 0.2039 - learning_rate: 5.0000e-04
# Epoch 36/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 971ms/step - accuracy: 0.9372 - loss: 0.1919
# Epoch 36: val_loss improved from 0.17046 to 0.15468, saving model to ApriTuttoDucciobackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 275s 1s/step - accuracy: 0.9372 - loss: 0.1919 - val_accuracy: 0.9461 - val_loss: 0.1547 - learning_rate: 5.0000e-04
# Epoch 37/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 970ms/step - accuracy: 0.9433 - loss: 0.1853
# Epoch 37: val_loss improved from 0.15468 to 0.15448, saving model to ApriTuttoDucciobackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 275s 1s/step - accuracy: 0.9433 - loss: 0.1853 - val_accuracy: 0.9477 - val_loss: 0.1545 - learning_rate: 5.0000e-04
# Epoch 38/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 967ms/step - accuracy: 0.9418 - loss: 0.1969
# Epoch 38: val_loss did not improve from 0.15448
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 272s 1s/step - accuracy: 0.9418 - loss: 0.1969 - val_accuracy: 0.9415 - val_loss: 0.1792 - learning_rate: 5.0000e-04
# Epoch 39/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 969ms/step - accuracy: 0.9479 - loss: 0.1703
# Epoch 39: val_loss improved from 0.15448 to 0.15017, saving model to ApriTuttoDucciobackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 275s 1s/step - accuracy: 0.9479 - loss: 0.1703 - val_accuracy: 0.9494 - val_loss: 0.1502 - learning_rate: 5.0000e-04
# Epoch 40/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 968ms/step - accuracy: 0.9463 - loss: 0.1779
# Epoch 40: val_loss did not improve from 0.15017
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 273s 1s/step - accuracy: 0.9463 - loss: 0.1779 - val_accuracy: 0.9477 - val_loss: 0.1538 - learning_rate: 5.0000e-04
# Epoch 41/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 968ms/step - accuracy: 0.9448 - loss: 0.1754
# Epoch 41: val_loss did not improve from 0.15017
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 272s 1s/step - accuracy: 0.9448 - loss: 0.1755 - val_accuracy: 0.9444 - val_loss: 0.1684 - learning_rate: 5.0000e-04
# Epoch 42/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 968ms/step - accuracy: 0.9454 - loss: 0.1813
# Epoch 42: val_loss improved from 0.15017 to 0.14774, saving model to ApriTuttoDucciobackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 274s 1s/step - accuracy: 0.9454 - loss: 0.1813 - val_accuracy: 0.9515 - val_loss: 0.1477 - learning_rate: 5.0000e-04
# Epoch 43/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 969ms/step - accuracy: 0.9472 - loss: 0.1711
# Epoch 43: val_loss did not improve from 0.14774
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 273s 1s/step - accuracy: 0.9472 - loss: 0.1711 - val_accuracy: 0.9452 - val_loss: 0.1621 - learning_rate: 5.0000e-04
# Epoch 44/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 967ms/step - accuracy: 0.9439 - loss: 0.1680
# Epoch 44: val_loss did not improve from 0.14774
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 272s 1s/step - accuracy: 0.9439 - loss: 0.1680 - val_accuracy: 0.9457 - val_loss: 0.1671 - learning_rate: 5.0000e-04
# Epoch 45/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 982ms/step - accuracy: 0.9415 - loss: 0.1986
# Epoch 45: val_loss improved from 0.14774 to 0.14477, saving model to ApriTuttoDucciobackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 279s 1s/step - accuracy: 0.9415 - loss: 0.1986 - val_accuracy: 0.9515 - val_loss: 0.1448 - learning_rate: 5.0000e-04
# Epoch 46/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 971ms/step - accuracy: 0.9538 - loss: 0.1578
# Epoch 46: val_loss did not improve from 0.14477
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 273s 1s/step - accuracy: 0.9537 - loss: 0.1578 - val_accuracy: 0.9465 - val_loss: 0.1612 - learning_rate: 5.0000e-04
# Epoch 47/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 967ms/step - accuracy: 0.9476 - loss: 0.1691
# Epoch 47: val_loss did not improve from 0.14477
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 272s 1s/step - accuracy: 0.9476 - loss: 0.1691 - val_accuracy: 0.9457 - val_loss: 0.1562 - learning_rate: 5.0000e-04
# Epoch 48/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 951ms/step - accuracy: 0.9455 - loss: 0.1646
# Epoch 48: val_loss did not improve from 0.14477
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 267s 1s/step - accuracy: 0.9455 - loss: 0.1646 - val_accuracy: 0.9494 - val_loss: 0.1479 - learning_rate: 5.0000e-04
# Epoch 49/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 937ms/step - accuracy: 0.9491 - loss: 0.1691
# Epoch 49: val_loss did not improve from 0.14477
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 263s 1s/step - accuracy: 0.9491 - loss: 0.1691 - val_accuracy: 0.9360 - val_loss: 0.1838 - learning_rate: 5.0000e-04
# Epoch 50/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 939ms/step - accuracy: 0.9404 - loss: 0.1768
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 50: val_loss did not improve from 0.14477
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.9404 - loss: 0.1767 - val_accuracy: 0.9511 - val_loss: 0.1490 - learning_rate: 5.0000e-04
# Epoch 51/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 939ms/step - accuracy: 0.9542 - loss: 0.1426
# Epoch 51: val_loss improved from 0.14477 to 0.12366, saving model to ApriTuttoDucciobackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 266s 1s/step - accuracy: 0.9542 - loss: 0.1426 - val_accuracy: 0.9553 - val_loss: 0.1237 - learning_rate: 2.5000e-04
# Epoch 52/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 938ms/step - accuracy: 0.9629 - loss: 0.1275
# Epoch 52: val_loss improved from 0.12366 to 0.12240, saving model to ApriTuttoDucciobackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 266s 1s/step - accuracy: 0.9629 - loss: 0.1275 - val_accuracy: 0.9548 - val_loss: 0.1224 - learning_rate: 2.5000e-04
# Epoch 53/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 942ms/step - accuracy: 0.9591 - loss: 0.1361
# Epoch 53: val_loss did not improve from 0.12240
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.9591 - loss: 0.1361 - val_accuracy: 0.9557 - val_loss: 0.1248 - learning_rate: 2.5000e-04
# Epoch 54/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 958ms/step - accuracy: 0.9597 - loss: 0.1278
# Epoch 54: val_loss improved from 0.12240 to 0.11133, saving model to ApriTuttoDucciobackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 271s 1s/step - accuracy: 0.9597 - loss: 0.1278 - val_accuracy: 0.9607 - val_loss: 0.1113 - learning_rate: 2.5000e-04
# Epoch 55/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 954ms/step - accuracy: 0.9612 - loss: 0.1353
# Epoch 55: val_loss did not improve from 0.11133
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 268s 1s/step - accuracy: 0.9612 - loss: 0.1353 - val_accuracy: 0.9582 - val_loss: 0.1176 - learning_rate: 2.5000e-04
# Epoch 56/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 956ms/step - accuracy: 0.9591 - loss: 0.1334
# Epoch 56: val_loss did not improve from 0.11133
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.9591 - loss: 0.1334 - val_accuracy: 0.9586 - val_loss: 0.1360 - learning_rate: 2.5000e-04
# Epoch 57/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 953ms/step - accuracy: 0.9631 - loss: 0.1238
# Epoch 57: val_loss did not improve from 0.11133
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 268s 1s/step - accuracy: 0.9631 - loss: 0.1238 - val_accuracy: 0.9574 - val_loss: 0.1420 - learning_rate: 2.5000e-04
# Epoch 58/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 956ms/step - accuracy: 0.9662 - loss: 0.1150
# Epoch 58: val_loss did not improve from 0.11133
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.9662 - loss: 0.1150 - val_accuracy: 0.9607 - val_loss: 0.1174 - learning_rate: 2.5000e-04
# Epoch 59/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 956ms/step - accuracy: 0.9699 - loss: 0.0998
# Epoch 59: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 59: val_loss did not improve from 0.11133
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 268s 1s/step - accuracy: 0.9699 - loss: 0.0998 - val_accuracy: 0.9511 - val_loss: 0.1535 - learning_rate: 2.5000e-04
# Epoch 60/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 955ms/step - accuracy: 0.9623 - loss: 0.1259
# Epoch 60: val_loss did not improve from 0.11133
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.9623 - loss: 0.1259 - val_accuracy: 0.9594 - val_loss: 0.1370 - learning_rate: 1.2500e-04
# Epoch 61/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 955ms/step - accuracy: 0.9702 - loss: 0.0904
# Epoch 61: val_loss did not improve from 0.11133
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.9702 - loss: 0.0904 - val_accuracy: 0.9645 - val_loss: 0.1202 - learning_rate: 1.2500e-04
# Epoch 62/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 955ms/step - accuracy: 0.9618 - loss: 0.1131
# Epoch 62: val_loss did not improve from 0.11133
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 268s 1s/step - accuracy: 0.9618 - loss: 0.1131 - val_accuracy: 0.9632 - val_loss: 0.1186 - learning_rate: 1.2500e-04
# Epoch 63/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 954ms/step - accuracy: 0.9643 - loss: 0.1015
# Epoch 63: val_loss improved from 0.11133 to 0.10948, saving model to ApriTuttoDucciobackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 271s 1s/step - accuracy: 0.9643 - loss: 0.1015 - val_accuracy: 0.9645 - val_loss: 0.1095 - learning_rate: 1.2500e-04
# Epoch 64/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 958ms/step - accuracy: 0.9712 - loss: 0.0923
# Epoch 64: val_loss did not improve from 0.10948
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.9712 - loss: 0.0923 - val_accuracy: 0.9624 - val_loss: 0.1130 - learning_rate: 1.2500e-04
# Epoch 65/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 955ms/step - accuracy: 0.9636 - loss: 0.1070
# Epoch 65: val_loss did not improve from 0.10948
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.9636 - loss: 0.1070 - val_accuracy: 0.9628 - val_loss: 0.1187 - learning_rate: 1.2500e-04
# Epoch 66/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 957ms/step - accuracy: 0.9702 - loss: 0.0919
# Epoch 66: val_loss improved from 0.10948 to 0.10196, saving model to ApriTuttoDucciobackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 271s 1s/step - accuracy: 0.9701 - loss: 0.0919 - val_accuracy: 0.9649 - val_loss: 0.1020 - learning_rate: 1.2500e-04
# Epoch 67/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 952ms/step - accuracy: 0.9648 - loss: 0.1106
# Epoch 67: val_loss did not improve from 0.10196
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 268s 1s/step - accuracy: 0.9648 - loss: 0.1106 - val_accuracy: 0.9607 - val_loss: 0.1240 - learning_rate: 1.2500e-04
# Epoch 68/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 956ms/step - accuracy: 0.9666 - loss: 0.0959
# Epoch 68: val_loss improved from 0.10196 to 0.09789, saving model to ApriTuttoDucciobackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 271s 1s/step - accuracy: 0.9666 - loss: 0.0959 - val_accuracy: 0.9628 - val_loss: 0.0979 - learning_rate: 1.2500e-04
# Epoch 69/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 957ms/step - accuracy: 0.9718 - loss: 0.0934
# Epoch 69: val_loss did not improve from 0.09789
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.9718 - loss: 0.0934 - val_accuracy: 0.9615 - val_loss: 0.1034 - learning_rate: 1.2500e-04
# Epoch 70/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 956ms/step - accuracy: 0.9714 - loss: 0.0948
# Epoch 70: val_loss did not improve from 0.09789
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.9714 - loss: 0.0949 - val_accuracy: 0.9645 - val_loss: 0.1037 - learning_rate: 1.2500e-04
# Epoch 71/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 956ms/step - accuracy: 0.9627 - loss: 0.1129
# Epoch 71: val_loss did not improve from 0.09789
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.9627 - loss: 0.1129 - val_accuracy: 0.9653 - val_loss: 0.1125 - learning_rate: 1.2500e-04
# Epoch 72/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 960ms/step - accuracy: 0.9721 - loss: 0.0855
# Epoch 72: val_loss did not improve from 0.09789
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 270s 1s/step - accuracy: 0.9721 - loss: 0.0855 - val_accuracy: 0.9653 - val_loss: 0.1168 - learning_rate: 1.2500e-04
# Epoch 73/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 958ms/step - accuracy: 0.9698 - loss: 0.0976
# Epoch 73: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 73: val_loss did not improve from 0.09789
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 270s 1s/step - accuracy: 0.9698 - loss: 0.0975 - val_accuracy: 0.9603 - val_loss: 0.1194 - learning_rate: 1.2500e-04
# Epoch 74/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 958ms/step - accuracy: 0.9727 - loss: 0.0899
# Epoch 74: val_loss did not improve from 0.09789
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.9727 - loss: 0.0899 - val_accuracy: 0.9628 - val_loss: 0.1106 - learning_rate: 6.2500e-05
# Epoch 75/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 959ms/step - accuracy: 0.9679 - loss: 0.0903
# Epoch 75: val_loss improved from 0.09789 to 0.09233, saving model to ApriTuttoDucciobackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 272s 1s/step - accuracy: 0.9679 - loss: 0.0903 - val_accuracy: 0.9661 - val_loss: 0.0923 - learning_rate: 6.2500e-05
# Epoch 76/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 960ms/step - accuracy: 0.9736 - loss: 0.0938
# Epoch 76: val_loss improved from 0.09233 to 0.08886, saving model to ApriTuttoDucciobackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 272s 1s/step - accuracy: 0.9736 - loss: 0.0938 - val_accuracy: 0.9703 - val_loss: 0.0889 - learning_rate: 6.2500e-05
# Epoch 77/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 959ms/step - accuracy: 0.9732 - loss: 0.0839
# Epoch 77: val_loss did not improve from 0.08886
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.9732 - loss: 0.0840 - val_accuracy: 0.9666 - val_loss: 0.1047 - learning_rate: 6.2500e-05
# Epoch 78/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 967ms/step - accuracy: 0.9743 - loss: 0.0842
# Epoch 78: val_loss improved from 0.08886 to 0.08535, saving model to ApriTuttoDucciobackup.keras
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 274s 1s/step - accuracy: 0.9743 - loss: 0.0842 - val_accuracy: 0.9707 - val_loss: 0.0853 - learning_rate: 6.2500e-05
# Epoch 79/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 969ms/step - accuracy: 0.9752 - loss: 0.0762
# Epoch 79: val_loss did not improve from 0.08535
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 273s 1s/step - accuracy: 0.9752 - loss: 0.0762 - val_accuracy: 0.9666 - val_loss: 0.0985 - learning_rate: 6.2500e-05
# Epoch 80/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 991ms/step - accuracy: 0.9728 - loss: 0.0911
# Epoch 80: val_loss did not improve from 0.08535
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 279s 1s/step - accuracy: 0.9728 - loss: 0.0911 - val_accuracy: 0.9686 - val_loss: 0.0966 - learning_rate: 6.2500e-05
# Epoch 81/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 971ms/step - accuracy: 0.9732 - loss: 0.0889
# Epoch 81: val_loss did not improve from 0.08535
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 273s 1s/step - accuracy: 0.9732 - loss: 0.0890 - val_accuracy: 0.9666 - val_loss: 0.1095 - learning_rate: 6.2500e-05
# Epoch 82/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 974ms/step - accuracy: 0.9731 - loss: 0.0866
# Epoch 82: val_loss did not improve from 0.08535
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 274s 1s/step - accuracy: 0.9731 - loss: 0.0866 - val_accuracy: 0.9657 - val_loss: 0.1100 - learning_rate: 6.2500e-05
# Epoch 83/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 974ms/step - accuracy: 0.9714 - loss: 0.0822
# Epoch 83: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 83: val_loss did not improve from 0.08535
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 274s 1s/step - accuracy: 0.9714 - loss: 0.0822 - val_accuracy: 0.9615 - val_loss: 0.1069 - learning_rate: 6.2500e-05
# Epoch 84/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 973ms/step - accuracy: 0.9776 - loss: 0.0700
# Epoch 84: val_loss did not improve from 0.08535
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 274s 1s/step - accuracy: 0.9776 - loss: 0.0700 - val_accuracy: 0.9645 - val_loss: 0.1160 - learning_rate: 3.1250e-05
# Epoch 85/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 971ms/step - accuracy: 0.9704 - loss: 0.0898
# Epoch 85: val_loss did not improve from 0.08535
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 273s 1s/step - accuracy: 0.9704 - loss: 0.0897 - val_accuracy: 0.9640 - val_loss: 0.1059 - learning_rate: 3.1250e-05
# Epoch 86/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 972ms/step - accuracy: 0.9761 - loss: 0.0789
# Epoch 86: val_loss did not improve from 0.08535
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 273s 1s/step - accuracy: 0.9760 - loss: 0.0789 - val_accuracy: 0.9699 - val_loss: 0.0978 - learning_rate: 3.1250e-05
# Epoch 87/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 972ms/step - accuracy: 0.9747 - loss: 0.0703
# Epoch 87: val_loss did not improve from 0.08535
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 273s 1s/step - accuracy: 0.9748 - loss: 0.0703 - val_accuracy: 0.9678 - val_loss: 0.0988 - learning_rate: 3.1250e-05
# Epoch 88/200
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 975ms/step - accuracy: 0.9729 - loss: 0.0824
# Epoch 88: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 88: val_loss did not improve from 0.08535
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 274s 1s/step - accuracy: 0.9729 - loss: 0.0824 - val_accuracy: 0.9695 - val_loss: 0.0974 - learning_rate: 3.1250e-05
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 3 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [error  ] Error occurred during asynchronous operation processing: Cannot upload file c:\content\drive\MyDrive\Colab Notebooks\the_boss.ipynb: Path not found or is a not a file.
# [neptune] [info   ] All 3 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/lp1807/Homework1/e/HOM-287/metadata

# %%
# prompt: plot loss and accuracy on training and validation through tranining

# Plot the training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# Plot the training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()
